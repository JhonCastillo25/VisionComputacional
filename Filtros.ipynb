# %% [markdown]
# #Aplicacion de kernels para encontrar bordes

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !mkdir clase1CV

# %%
# !cp /content/drive/MyDrive/Vision_Computacional/imagenes_clase1.zip /content/clase1CV/

# %%
# %cd clase1CV/
# !pwd
# Out:
# /content/clase1CV
# /content/clase1CV

# %%
# !unzip imagenes_clase1
# Out:
# Archive:  imagenes_clase1.zip
#   inflating: casa.jpg
#   inflating: gradients.jpg
#  extracting: ladder.png

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %% [markdown]
# Lectura de imagenes

# %%
img1 = cv2.imread('NoiseLena.png')
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) #pasar imagen a escala de grises
cv2_imshow(img)
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=RGB size=512x341 at 0x7FB0415B3F90>
# <PIL.Image.Image image mode=L size=512x341 at 0x7FB04152EED0>

# %% [markdown]
# CREAR LAPLACIANO USANDO NUMPY

# %%
lap = np.array(([0,1,0],[1,-4,1],[0,1,0]),dtype='int')
bordes_lap = cv2.filter2D(img, -1 ,lap)
cv2_imshow(bordes_lap)
# Out:
# <PIL.Image.Image image mode=RGB size=512x341 at 0x7FB0415393D0>

# %%
#sobel X y Y

Sx=np.array(([-1,0,1],[-2,0,2],[-1,0,1]),dtype='int')
Sy=np.array(([1,2,1],[0,0,0],[-1,-2,-1]),dtype='int')

img_SobelX=  cv2.filter2D(img, -1 ,Sx)
img_SobelY=  cv2.filter2D(img, -1 ,Sy)

cv2_imshow(img_SobelX)
cv2_imshow(img_SobelY)

# %%
from matplotlib import pyplot as plt

SobelX= cv2.Sobel(img_gray, cv2.CV_64F ,1,0, ksize=3)
SobelY= cv2.Sobel(img_gray, cv2.CV_64F ,0,1, ksize=3)
laplaciano= cv2.Laplacian(img_gray, cv2.CV_64F)

plt.subplot(2,2,1),plt.imshow(img_gray,cmap='gray')
plt.subplot(2,2,2),plt.imshow(laplaciano,cmap='gray')
plt.subplot(2,2,3),plt.imshow(SobelX,cmap='gray')
plt.subplot(2,2,4),plt.imshow(SobelY,cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8e7415548ef2> in <module>()
#       1 from matplotlib import pyplot as plt
#       2
# ----> 3 SobelX= cv2.Sobel(img_gray, cv2.CV_64F ,1,0, ksize=3)
#       4 SobelY= cv2.Sobel(img_gray, cv2.CV_64F ,0,1, ksize=3)
#       5 laplaciano= cv2.Laplacian(img_gray, cv2.CV_64F)
#
# NameError: name 'cv2' is not defined

# %%
img_lena = cv2.imread('NoiseLena.png')
img_Lena_sr= cv2.blur(img_lena,(3,3))

cv2_imshow(img_lena)
cv2_imshow(img_Lena_sr)
# Out:
# <PIL.Image.Image image mode=RGB size=254x254 at 0x7F450D5F2DD0>
# <PIL.Image.Image image mode=RGB size=254x254 at 0x7F450D5F2050>
