# %% [markdown]
# ## LABORATORIO 2
#
# DETECCION DE TORTUGAS Y PECES
# CUADERNO DE TEST
#
# JHON JAIRO CASTILLO
#
# JUAN CAMILO TOBAR
#
#
# En este cuaderno se realiza la deteccion sobre las imagenes de test asi como la deteccion sobre video

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %% [markdown]
# ### Import libs

# %%
from __future__ import division
from __future__ import print_function
from __future__ import absolute_import
import random
import pprint
import sys
import time
import numpy as np
from optparse import OptionParser
import pickle
import math
import cv2
import copy
from matplotlib import pyplot as plt
import tensorflow as tf
import pandas as pd
import os

from sklearn.metrics import average_precision_score

from keras import backend as K
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from keras.layers import Flatten, Dense, Input, Conv2D, MaxPooling2D, Dropout
from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, TimeDistributed
from keras.utils.layer_utils import get_source_inputs
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.losses import categorical_crossentropy

from keras.models import Model
from keras.utils import generic_utils
from keras.engine.base_layer import Layer, InputSpec
from keras import initializers, regularizers

# %% [markdown]
# #### Config setting

# %%
class Config:

	def __init__(self):

		# Print the process or not
		self.verbose = True

		# Name of base network
		self.network = 'vgg'

		# Setting for data augmentation
		self.use_horizontal_flips = False
		self.use_vertical_flips = False
		self.rot_90 = False

		# Anchor box scales
    # Note that if im_size is smaller, anchor_box_scales should be scaled
    # Original anchor_box_scales in the paper is [128, 256, 512]
		self.anchor_box_scales = [64, 128, 256] 

		# Anchor box ratios
		self.anchor_box_ratios = [[1, 1], [1./math.sqrt(2), 2./math.sqrt(2)], [2./math.sqrt(2), 1./math.sqrt(2)]]

		# Size to resize the smallest side of the image
		# Original setting in paper is 600. Set to 300 in here to save training time
		self.im_size = 300

		# image channel-wise mean to subtract
		self.img_channel_mean = [103.939, 116.779, 123.68]
		self.img_scaling_factor = 1.0

		# number of ROIs at once
		self.num_rois = 4

		# stride at the RPN (this depends on the network configuration)
		self.rpn_stride = 16

		self.balanced_classes = False

		# scaling the stdev
		self.std_scaling = 4.0
		self.classifier_regr_std = [8.0, 8.0, 4.0, 4.0]

		# overlaps for RPN
		self.rpn_min_overlap = 0.3
		self.rpn_max_overlap = 0.7

		# overlaps for classifier ROIs
		self.classifier_min_overlap = 0.1
		self.classifier_max_overlap = 0.5

		# placeholder for the class mapping, automatically generated by the parser
		self.class_mapping = None

		self.model_path = None

# %% [markdown]
# #### Parser the data from annotation file

# %%
def get_data(input_path):
	"""Parser the data from annotation file
	
	Args:
		input_path: annotation file path

	Returns:
		all_data: list(filepath, width, height, list(bboxes))
		classes_count: dict{key:class_name, value:count_num} 
			e.g. {'Car': 2383, 'Mobile phone': 1108, 'Person': 3745}
		class_mapping: dict{key:class_name, value: idx}
			e.g. {'Car': 0, 'Mobile phone': 1, 'Person': 2}
	"""
	found_bg = False
	all_imgs = {}

	classes_count = {}

	class_mapping = {}

	visualise = True

	i = 1
	
	with open(input_path,'r') as f:

		print('Parsing annotation files')

		for line in f:

			# Print process
			sys.stdout.write('\r'+'idx=' + str(i))
			i += 1

			line_split = line.strip().split(',')

			# Make sure the info saved in annotation file matching the format (path_filename, x1, y1, x2, y2, class_name)
			# Note:
			#	One path_filename might has several classes (class_name)
			#	x1, y1, x2, y2 are the pixel value of the origial image, not the ratio value
			#	(x1, y1) top left coordinates; (x2, y2) bottom right coordinates
			#   x1,y1-------------------
			#	|						|
			#	|						|
			#	|						|
			#	|						|
			#	---------------------x2,y2

			(filename,x1,y1,x2,y2,class_name) = line_split

			if class_name not in classes_count:
				classes_count[class_name] = 1
			else:
				classes_count[class_name] += 1

			if class_name not in class_mapping:
				if class_name == 'bg' and found_bg == False:
					print('Found class name with special name bg. Will be treated as a background region (this is usually for hard negative mining).')
					found_bg = True
				class_mapping[class_name] = len(class_mapping)

			if filename not in all_imgs:
				all_imgs[filename] = {}
				
				img = cv2.imread(filename)
				(rows,cols) = img.shape[:2]
				all_imgs[filename]['filepath'] = filename
				all_imgs[filename]['width'] = cols
				all_imgs[filename]['height'] = rows
				all_imgs[filename]['bboxes'] = []
				# if np.random.randint(0,6) > 0:
				# 	all_imgs[filename]['imageset'] = 'trainval'
				# else:
				# 	all_imgs[filename]['imageset'] = 'test'

			all_imgs[filename]['bboxes'].append({'class': class_name, 'x1': int(x1), 'x2': int(x2), 'y1': int(y1), 'y2': int(y2)})


		all_data = []
		for key in all_imgs:
			all_data.append(all_imgs[key])
		
		# make sure the bg class is last in the list
		if found_bg:
			if class_mapping['bg'] != len(class_mapping) - 1:
				key_to_switch = [key for key in class_mapping.keys() if class_mapping[key] == len(class_mapping)-1][0]
				val_to_switch = class_mapping['bg']
				class_mapping['bg'] = len(class_mapping) - 1
				class_mapping[key_to_switch] = val_to_switch
		
		return all_data, classes_count, class_mapping

# %% [markdown]
# #### Define ROI Pooling Convolutional Layer

# %%
class RoiPoolingConv(Layer):
    '''ROI pooling layer for 2D inputs.
    See Spatial Pyramid Pooling in Deep Convolutional Networks for Visual Recognition,
    K. He, X. Zhang, S. Ren, J. Sun
    # Arguments
        pool_size: int
            Size of pooling region to use. pool_size = 7 will result in a 7x7 region.
        num_rois: number of regions of interest to be used
    # Input shape
        list of two 4D tensors [X_img,X_roi] with shape:
        X_img:
        `(1, rows, cols, channels)`
        X_roi:
        `(1,num_rois,4)` list of rois, with ordering (x,y,w,h)
    # Output shape
        3D tensor with shape:
        `(1, num_rois, channels, pool_size, pool_size)`
    '''
    def __init__(self, pool_size, num_rois, **kwargs):

        #self.dim_ordering = K.image_dim_ordering()
        self.dim_ordering = K.image_data_format()
        self.pool_size = pool_size
        self.num_rois = num_rois

        super(RoiPoolingConv, self).__init__(**kwargs)

    def build(self, input_shape):
        self.nb_channels = input_shape[0][3]   

    def compute_output_shape(self, input_shape):
        return None, self.num_rois, self.pool_size, self.pool_size, self.nb_channels

    def call(self, x, mask=None):

        assert(len(x) == 2)

        # x[0] is image with shape (rows, cols, channels)
        img = x[0]

        # x[1] is roi with shape (num_rois,4) with ordering (x,y,w,h)
        rois = x[1]

        input_shape = K.shape(img)

        outputs = []

        for roi_idx in range(self.num_rois):

            x = rois[0, roi_idx, 0]
            y = rois[0, roi_idx, 1]
            w = rois[0, roi_idx, 2]
            h = rois[0, roi_idx, 3]

            x = K.cast(x, 'int32')
            y = K.cast(y, 'int32')
            w = K.cast(w, 'int32')
            h = K.cast(h, 'int32')

            # Resized roi of the image to pooling size (7x7)
            rs = tf.image.resize(img[:, y:y+h, x:x+w, :], (self.pool_size, self.pool_size))
            outputs.append(rs)
                

        final_output = K.concatenate(outputs, axis=0)

        # Reshape to (1, num_rois, pool_size, pool_size, nb_channels)
        # Might be (1, 4, 7, 7, 3)
        final_output = K.reshape(final_output, (1, self.num_rois, self.pool_size, self.pool_size, self.nb_channels))

        # permute_dimensions is similar to transpose
        final_output = K.permute_dimensions(final_output, (0, 1, 2, 3, 4))

        return final_output
    
    
    def get_config(self):
        config = {'pool_size': self.pool_size,
                  'num_rois': self.num_rois}
        base_config = super(RoiPoolingConv, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# #### Vgg-16 model

# %%
def get_img_output_length(width, height):
    def get_output_length(input_length):
        return input_length//16

    return get_output_length(width), get_output_length(height)    

def nn_base(input_tensor=None, trainable=False):


    input_shape = (None, None, 3)

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    bn_axis = 3

    # Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
    # x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

    return x

# %% [markdown]
# ####  RPN layer

# %%
def rpn_layer(base_layers, num_anchors):
    """Create a rpn layer
        Step1: Pass through the feature map from base layer to a 3x3 512 channels convolutional layer
                Keep the padding 'same' to preserve the feature map's size
        Step2: Pass the step1 to two (1,1) convolutional layer to replace the fully connected layer
                classification layer: num_anchors (9 in here) channels for 0, 1 sigmoid activation output
                regression layer: num_anchors*4 (36 in here) channels for computing the regression of bboxes with linear activation
    Args:
        base_layers: vgg in here
        num_anchors: 9 in here

    Returns:
        [x_class, x_regr, base_layers]
        x_class: classification for whether it's an object
        x_regr: bboxes regression
        base_layers: vgg in here
    """
    x = Conv2D(512, (3, 3), padding='same', activation='relu', kernel_initializer='normal', name='rpn_conv1')(base_layers)

    x_class = Conv2D(num_anchors, (1, 1), activation='sigmoid', kernel_initializer='uniform', name='rpn_out_class')(x)
    x_regr = Conv2D(num_anchors * 4, (1, 1), activation='linear', kernel_initializer='zero', name='rpn_out_regress')(x)

    return [x_class, x_regr, base_layers]

# %% [markdown]
# ####  Classifier layer

# %%
def classifier_layer(base_layers, input_rois, num_rois, nb_classes = 4):
    """Create a classifier layer
    
    Args:
        base_layers: vgg
        input_rois: `(1,num_rois,4)` list of rois, with ordering (x,y,w,h)
        num_rois: number of rois to be processed in one time (4 in here)

    Returns:
        list(out_class, out_regr)
        out_class: classifier layer output
        out_regr: regression layer output
    """

    input_shape = (num_rois,7,7,512)

    pooling_regions = 7

    # out_roi_pool.shape = (1, num_rois, channels, pool_size, pool_size)
    # num_rois (4) 7x7 roi pooling
    out_roi_pool = RoiPoolingConv(pooling_regions, num_rois)([base_layers, input_rois])

    # Flatten the convlutional layer and connected to 2 FC and 2 dropout
    out = TimeDistributed(Flatten(name='flatten'))(out_roi_pool)
    out = TimeDistributed(Dense(4096, activation='relu', name='fc1'))(out)
    out = TimeDistributed(Dropout(0.5))(out)
    out = TimeDistributed(Dense(4096, activation='relu', name='fc2'))(out)
    out = TimeDistributed(Dropout(0.5))(out)

    # There are two output layer
    # out_class: softmax acivation function for classify the class name of the object
    # out_regr: linear activation function for bboxes coordinates regression
    out_class = TimeDistributed(Dense(nb_classes, activation='softmax', kernel_initializer='zero'), name='dense_class_{}'.format(nb_classes))(out)
    # note: no regression target for bg class
    out_regr = TimeDistributed(Dense(4 * (nb_classes-1), activation='linear', kernel_initializer='zero'), name='dense_regress_{}'.format(nb_classes))(out)

    return [out_class, out_regr]

# %% [markdown]
# #### Calculate IoU (Intersection of Union)

# %%
def union(au, bu, area_intersection):
	area_a = (au[2] - au[0]) * (au[3] - au[1])
	area_b = (bu[2] - bu[0]) * (bu[3] - bu[1])
	area_union = area_a + area_b - area_intersection
	return area_union


def intersection(ai, bi):
	x = max(ai[0], bi[0])
	y = max(ai[1], bi[1])
	w = min(ai[2], bi[2]) - x
	h = min(ai[3], bi[3]) - y
	if w < 0 or h < 0:
		return 0
	return w*h


def iou(a, b):
	# a and b should be (x1,y1,x2,y2)

	if a[0] >= a[2] or a[1] >= a[3] or b[0] >= b[2] or b[1] >= b[3]:
		return 0.0

	area_i = intersection(a, b)
	area_u = union(a, b, area_i)

	return float(area_i) / float(area_u + 1e-6)

# %% [markdown]
# #### Calculate the rpn for all anchors of all images

# %%
def calc_rpn(C, img_data, width, height, resized_width, resized_height, img_length_calc_function):
	"""(Important part!) Calculate the rpn for all anchors 
		If feature map has shape 38x50=1900, there are 1900x9=17100 potential anchors
	
	Args:
		C: config
		img_data: augmented image data
		width: original image width (e.g. 600)
		height: original image height (e.g. 800)
		resized_width: resized image width according to C.im_size (e.g. 300)
		resized_height: resized image height according to C.im_size (e.g. 400)
		img_length_calc_function: function to calculate final layer's feature map (of base model) size according to input image size

	Returns:
		y_rpn_cls: list(num_bboxes, y_is_box_valid + y_rpn_overlap)
			y_is_box_valid: 0 or 1 (0 means the box is invalid, 1 means the box is valid)
			y_rpn_overlap: 0 or 1 (0 means the box is not an object, 1 means the box is an object)
		y_rpn_regr: list(num_bboxes, 4*y_rpn_overlap + y_rpn_regr)
			y_rpn_regr: x1,y1,x2,y2 bunding boxes coordinates
	"""
	downscale = float(C.rpn_stride) 
	anchor_sizes = C.anchor_box_scales   # 128, 256, 512
	anchor_ratios = C.anchor_box_ratios  # 1:1, 1:2*sqrt(2), 2*sqrt(2):1
	num_anchors = len(anchor_sizes) * len(anchor_ratios) # 3x3=9

	# calculate the output map size based on the network architecture
	(output_width, output_height) = img_length_calc_function(resized_width, resized_height)

	n_anchratios = len(anchor_ratios)    # 3
	
	# initialise empty output objectives
	y_rpn_overlap = np.zeros((output_height, output_width, num_anchors))
	y_is_box_valid = np.zeros((output_height, output_width, num_anchors))
	y_rpn_regr = np.zeros((output_height, output_width, num_anchors * 4))

	num_bboxes = len(img_data['bboxes'])

	num_anchors_for_bbox = np.zeros(num_bboxes).astype(int)
	best_anchor_for_bbox = -1*np.ones((num_bboxes, 4)).astype(int)
	best_iou_for_bbox = np.zeros(num_bboxes).astype(np.float32)
	best_x_for_bbox = np.zeros((num_bboxes, 4)).astype(int)
	best_dx_for_bbox = np.zeros((num_bboxes, 4)).astype(np.float32)

	# get the GT box coordinates, and resize to account for image resizing
	gta = np.zeros((num_bboxes, 4))
	for bbox_num, bbox in enumerate(img_data['bboxes']):
		# get the GT box coordinates, and resize to account for image resizing
		gta[bbox_num, 0] = bbox['x1'] * (resized_width / float(width))
		gta[bbox_num, 1] = bbox['x2'] * (resized_width / float(width))
		gta[bbox_num, 2] = bbox['y1'] * (resized_height / float(height))
		gta[bbox_num, 3] = bbox['y2'] * (resized_height / float(height))
	
	# rpn ground truth

	for anchor_size_idx in range(len(anchor_sizes)):
		for anchor_ratio_idx in range(n_anchratios):
			anchor_x = anchor_sizes[anchor_size_idx] * anchor_ratios[anchor_ratio_idx][0]
			anchor_y = anchor_sizes[anchor_size_idx] * anchor_ratios[anchor_ratio_idx][1]	
			
			for ix in range(output_width):					
				# x-coordinates of the current anchor box	
				x1_anc = downscale * (ix + 0.5) - anchor_x / 2
				x2_anc = downscale * (ix + 0.5) + anchor_x / 2	
				
				# ignore boxes that go across image boundaries					
				if x1_anc < 0 or x2_anc > resized_width:
					continue
					
				for jy in range(output_height):

					# y-coordinates of the current anchor box
					y1_anc = downscale * (jy + 0.5) - anchor_y / 2
					y2_anc = downscale * (jy + 0.5) + anchor_y / 2

					# ignore boxes that go across image boundaries
					if y1_anc < 0 or y2_anc > resized_height:
						continue

					# bbox_type indicates whether an anchor should be a target
					# Initialize with 'negative'
					bbox_type = 'neg'

					# this is the best IOU for the (x,y) coord and the current anchor
					# note that this is different from the best IOU for a GT bbox
					best_iou_for_loc = 0.0

					for bbox_num in range(num_bboxes):
						
						# get IOU of the current GT box and the current anchor box
						curr_iou = iou([gta[bbox_num, 0], gta[bbox_num, 2], gta[bbox_num, 1], gta[bbox_num, 3]], [x1_anc, y1_anc, x2_anc, y2_anc])
						# calculate the regression targets if they will be needed
						if curr_iou > best_iou_for_bbox[bbox_num] or curr_iou > C.rpn_max_overlap:
							cx = (gta[bbox_num, 0] + gta[bbox_num, 1]) / 2.0
							cy = (gta[bbox_num, 2] + gta[bbox_num, 3]) / 2.0
							cxa = (x1_anc + x2_anc)/2.0
							cya = (y1_anc + y2_anc)/2.0

							# x,y are the center point of ground-truth bbox
							# xa,ya are the center point of anchor bbox (xa=downscale * (ix + 0.5); ya=downscale * (iy+0.5))
							# w,h are the width and height of ground-truth bbox
							# wa,ha are the width and height of anchor bboxe
							# tx = (x - xa) / wa
							# ty = (y - ya) / ha
							# tw = log(w / wa)
							# th = log(h / ha)
							tx = (cx - cxa) / (x2_anc - x1_anc)
							ty = (cy - cya) / (y2_anc - y1_anc)
							tw = np.log((gta[bbox_num, 1] - gta[bbox_num, 0]) / (x2_anc - x1_anc))
							th = np.log((gta[bbox_num, 3] - gta[bbox_num, 2]) / (y2_anc - y1_anc))
						
						if img_data['bboxes'][bbox_num]['class'] != 'bg':

							# all GT boxes should be mapped to an anchor box, so we keep track of which anchor box was best
							if curr_iou > best_iou_for_bbox[bbox_num]:
								best_anchor_for_bbox[bbox_num] = [jy, ix, anchor_ratio_idx, anchor_size_idx]
								best_iou_for_bbox[bbox_num] = curr_iou
								best_x_for_bbox[bbox_num,:] = [x1_anc, x2_anc, y1_anc, y2_anc]
								best_dx_for_bbox[bbox_num,:] = [tx, ty, tw, th]

							# we set the anchor to positive if the IOU is >0.7 (it does not matter if there was another better box, it just indicates overlap)
							if curr_iou > C.rpn_max_overlap:
								bbox_type = 'pos'
								num_anchors_for_bbox[bbox_num] += 1
								# we update the regression layer target if this IOU is the best for the current (x,y) and anchor position
								if curr_iou > best_iou_for_loc:
									best_iou_for_loc = curr_iou
									best_regr = (tx, ty, tw, th)

							# if the IOU is >0.3 and <0.7, it is ambiguous and no included in the objective
							if C.rpn_min_overlap < curr_iou < C.rpn_max_overlap:
								# gray zone between neg and pos
								if bbox_type != 'pos':
									bbox_type = 'neutral'

					# turn on or off outputs depending on IOUs
					if bbox_type == 'neg':
						y_is_box_valid[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 1
						y_rpn_overlap[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 0
					elif bbox_type == 'neutral':
						y_is_box_valid[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 0
						y_rpn_overlap[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 0
					elif bbox_type == 'pos':
						y_is_box_valid[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 1
						y_rpn_overlap[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 1
						start = 4 * (anchor_ratio_idx + n_anchratios * anchor_size_idx)
						y_rpn_regr[jy, ix, start:start+4] = best_regr

	# we ensure that every bbox has at least one positive RPN region

	for idx in range(num_anchors_for_bbox.shape[0]):
		if num_anchors_for_bbox[idx] == 0:
			# no box with an IOU greater than zero ...
			if best_anchor_for_bbox[idx, 0] == -1:
				continue
			y_is_box_valid[
				best_anchor_for_bbox[idx,0], best_anchor_for_bbox[idx,1], best_anchor_for_bbox[idx,2] + n_anchratios *
				best_anchor_for_bbox[idx,3]] = 1
			y_rpn_overlap[
				best_anchor_for_bbox[idx,0], best_anchor_for_bbox[idx,1], best_anchor_for_bbox[idx,2] + n_anchratios *
				best_anchor_for_bbox[idx,3]] = 1
			start = 4 * (best_anchor_for_bbox[idx,2] + n_anchratios * best_anchor_for_bbox[idx,3])
			y_rpn_regr[
				best_anchor_for_bbox[idx,0], best_anchor_for_bbox[idx,1], start:start+4] = best_dx_for_bbox[idx, :]

	y_rpn_overlap = np.transpose(y_rpn_overlap, (2, 0, 1))
	y_rpn_overlap = np.expand_dims(y_rpn_overlap, axis=0)

	y_is_box_valid = np.transpose(y_is_box_valid, (2, 0, 1))
	y_is_box_valid = np.expand_dims(y_is_box_valid, axis=0)

	y_rpn_regr = np.transpose(y_rpn_regr, (2, 0, 1))
	y_rpn_regr = np.expand_dims(y_rpn_regr, axis=0)

	pos_locs = np.where(np.logical_and(y_rpn_overlap[0, :, :, :] == 1, y_is_box_valid[0, :, :, :] == 1))
	neg_locs = np.where(np.logical_and(y_rpn_overlap[0, :, :, :] == 0, y_is_box_valid[0, :, :, :] == 1))

	num_pos = len(pos_locs[0])

	# one issue is that the RPN has many more negative than positive regions, so we turn off some of the negative
	# regions. We also limit it to 256 regions.
	num_regions = 256

	if len(pos_locs[0]) > num_regions/2:
		val_locs = random.sample(range(len(pos_locs[0])), len(pos_locs[0]) - num_regions/2)
		y_is_box_valid[0, pos_locs[0][val_locs], pos_locs[1][val_locs], pos_locs[2][val_locs]] = 0
		num_pos = num_regions/2

	if len(neg_locs[0]) + num_pos > num_regions:
		val_locs = random.sample(range(len(neg_locs[0])), len(neg_locs[0]) - num_pos)
		y_is_box_valid[0, neg_locs[0][val_locs], neg_locs[1][val_locs], neg_locs[2][val_locs]] = 0

	y_rpn_cls = np.concatenate([y_is_box_valid, y_rpn_overlap], axis=1)
	y_rpn_regr = np.concatenate([np.repeat(y_rpn_overlap, 4, axis=1), y_rpn_regr], axis=1)

	return np.copy(y_rpn_cls), np.copy(y_rpn_regr), num_pos

# %% [markdown]
# #### Get new image size and augment the image

# %%
def get_new_img_size(width, height, img_min_side=300):
	if width <= height:
		f = float(img_min_side) / width
		resized_height = int(f * height)
		resized_width = img_min_side
	else:
		f = float(img_min_side) / height
		resized_width = int(f * width)
		resized_height = img_min_side

	return resized_width, resized_height

def augment(img_data, config, augment=True):
	assert 'filepath' in img_data
	assert 'bboxes' in img_data
	assert 'width' in img_data
	assert 'height' in img_data

	img_data_aug = copy.deepcopy(img_data)

	img = cv2.imread(img_data_aug['filepath'])

	if augment:
		rows, cols = img.shape[:2]

		if config.use_horizontal_flips and np.random.randint(0, 2) == 0:
			img = cv2.flip(img, 1)
			for bbox in img_data_aug['bboxes']:
				x1 = bbox['x1']
				x2 = bbox['x2']
				bbox['x2'] = cols - x1
				bbox['x1'] = cols - x2

		if config.use_vertical_flips and np.random.randint(0, 2) == 0:
			img = cv2.flip(img, 0)
			for bbox in img_data_aug['bboxes']:
				y1 = bbox['y1']
				y2 = bbox['y2']
				bbox['y2'] = rows - y1
				bbox['y1'] = rows - y2

		if config.rot_90:
			angle = np.random.choice([0,90,180,270],1)[0]
			if angle == 270:
				img = np.transpose(img, (1,0,2))
				img = cv2.flip(img, 0)
			elif angle == 180:
				img = cv2.flip(img, -1)
			elif angle == 90:
				img = np.transpose(img, (1,0,2))
				img = cv2.flip(img, 1)
			elif angle == 0:
				pass

			for bbox in img_data_aug['bboxes']:
				x1 = bbox['x1']
				x2 = bbox['x2']
				y1 = bbox['y1']
				y2 = bbox['y2']
				if angle == 270:
					bbox['x1'] = y1
					bbox['x2'] = y2
					bbox['y1'] = cols - x2
					bbox['y2'] = cols - x1
				elif angle == 180:
					bbox['x2'] = cols - x1
					bbox['x1'] = cols - x2
					bbox['y2'] = rows - y1
					bbox['y1'] = rows - y2
				elif angle == 90:
					bbox['x1'] = rows - y2
					bbox['x2'] = rows - y1
					bbox['y1'] = x1
					bbox['y2'] = x2        
				elif angle == 0:
					pass

	img_data_aug['width'] = img.shape[1]
	img_data_aug['height'] = img.shape[0]
	return img_data_aug, img

# %% [markdown]
# #### Generate the ground_truth anchors

# %%
def get_anchor_gt(all_img_data, C, img_length_calc_function, mode='train'):
	""" Yield the ground-truth anchors as Y (labels)
		
	Args:
		all_img_data: list(filepath, width, height, list(bboxes))
		C: config
		img_length_calc_function: function to calculate final layer's feature map (of base model) size according to input image size
		mode: 'train' or 'test'; 'train' mode need augmentation

	Returns:
		x_img: image data after resized and scaling (smallest size = 300px)
		Y: [y_rpn_cls, y_rpn_regr]
		img_data_aug: augmented image data (original image with augmentation)
		debug_img: show image for debug
		num_pos: show number of positive anchors for debug
	"""
	while True:

		for img_data in all_img_data:
			try:

				# read in image, and optionally add augmentation

				if mode == 'train':
					img_data_aug, x_img = augment(img_data, C, augment=True)
				else:
					img_data_aug, x_img = augment(img_data, C, augment=False)

				(width, height) = (img_data_aug['width'], img_data_aug['height'])
				(rows, cols, _) = x_img.shape

				assert cols == width
				assert rows == height

				# get image dimensions for resizing
				(resized_width, resized_height) = get_new_img_size(width, height, C.im_size)

				# resize the image so that smalles side is length = 300px
				x_img = cv2.resize(x_img, (resized_width, resized_height), interpolation=cv2.INTER_CUBIC)
				debug_img = x_img.copy()

				try:
					y_rpn_cls, y_rpn_regr, num_pos = calc_rpn(C, img_data_aug, width, height, resized_width, resized_height, img_length_calc_function)
				except:
					continue

				# Zero-center by mean pixel, and preprocess image

				x_img = x_img[:,:, (2, 1, 0)]  # BGR -> RGB
				x_img = x_img.astype(np.float32)
				x_img[:, :, 0] -= C.img_channel_mean[0]
				x_img[:, :, 1] -= C.img_channel_mean[1]
				x_img[:, :, 2] -= C.img_channel_mean[2]
				x_img /= C.img_scaling_factor

				x_img = np.transpose(x_img, (2, 0, 1))
				x_img = np.expand_dims(x_img, axis=0)

				y_rpn_regr[:, y_rpn_regr.shape[1]//2:, :, :] *= C.std_scaling

				x_img = np.transpose(x_img, (0, 2, 3, 1))
				y_rpn_cls = np.transpose(y_rpn_cls, (0, 2, 3, 1))
				y_rpn_regr = np.transpose(y_rpn_regr, (0, 2, 3, 1))

				yield np.copy(x_img), [np.copy(y_rpn_cls), np.copy(y_rpn_regr)], img_data_aug, debug_img, num_pos

			except Exception as e:
				print(e)
				continue

# %%
def non_max_suppression_fast(boxes, probs, overlap_thresh=0.9, max_boxes=300):
	# code used from here: http://www.pyimagesearch.com/2015/02/16/faster-non-maximum-suppression-python/
	# if there are no boxes, return an empty list
  
    # Process explanation:
    #   Step 1: Sort the probs list
    #   Step 2: Find the larget prob 'Last' in the list and save it to the pick list
    #   Step 3: Calculate the IoU with 'Last' box and other boxes in the list. If the IoU is larger than overlap_threshold, delete the box from list
    #   Step 4: Repeat step 2 and step 3 until there is no item in the probs list 
	if len(boxes) == 0:
		return []

	# grab the coordinates of the bounding boxes
	x1 = boxes[:, 0]
	y1 = boxes[:, 1]
	x2 = boxes[:, 2]
	y2 = boxes[:, 3]

	np.testing.assert_array_less(x1, x2)
	np.testing.assert_array_less(y1, y2)

	# if the bounding boxes integers, convert them to floats --
	# this is important since we'll be doing a bunch of divisions
	if boxes.dtype.kind == "i":
		boxes = boxes.astype("float")

	# initialize the list of picked indexes	
	pick = []

	# calculate the areas
	area = (x2 - x1) * (y2 - y1)

	# sort the bounding boxes 
	idxs = np.argsort(probs)

	# keep looping while some indexes still remain in the indexes
	# list
	while len(idxs) > 0:
		# grab the last index in the indexes list and add the
		# index value to the list of picked indexes
		last = len(idxs) - 1
		i = idxs[last]
		pick.append(i)

		# find the intersection

		xx1_int = np.maximum(x1[i], x1[idxs[:last]])
		yy1_int = np.maximum(y1[i], y1[idxs[:last]])
		xx2_int = np.minimum(x2[i], x2[idxs[:last]])
		yy2_int = np.minimum(y2[i], y2[idxs[:last]])

		ww_int = np.maximum(0, xx2_int - xx1_int)
		hh_int = np.maximum(0, yy2_int - yy1_int)

		area_int = ww_int * hh_int

		# find the union
		area_union = area[i] + area[idxs[:last]] - area_int

		# compute the ratio of overlap
		overlap = area_int/(area_union + 1e-6)

		# delete all indexes from the index list that have
		idxs = np.delete(idxs, np.concatenate(([last],
			np.where(overlap > overlap_thresh)[0])))

		if len(pick) >= max_boxes:
			break

	# return only the bounding boxes that were picked using the integer data type
	boxes = boxes[pick].astype("int")
	probs = probs[pick]
	return boxes, probs

def apply_regr_np(X, T):
	"""Apply regression layer to all anchors in one feature map

	Args:
		X: shape=(4, 18, 25) the current anchor type for all points in the feature map
		T: regression layer shape=(4, 18, 25)

	Returns:
		X: regressed position and size for current anchor
	"""
	try:
		x = X[0, :, :]
		y = X[1, :, :]
		w = X[2, :, :]
		h = X[3, :, :]

		tx = T[0, :, :]
		ty = T[1, :, :]
		tw = T[2, :, :]
		th = T[3, :, :]

		cx = x + w/2.
		cy = y + h/2.
		cx1 = tx * w + cx
		cy1 = ty * h + cy

		w1 = np.exp(tw.astype(np.float64)) * w
		h1 = np.exp(th.astype(np.float64)) * h
		x1 = cx1 - w1/2.
		y1 = cy1 - h1/2.

		x1 = np.round(x1)
		y1 = np.round(y1)
		w1 = np.round(w1)
		h1 = np.round(h1)
		return np.stack([x1, y1, w1, h1])
	except Exception as e:
		print(e)
		return X
    
def apply_regr(x, y, w, h, tx, ty, tw, th):
    # Apply regression to x, y, w and h
	try:
		cx = x + w/2.
		cy = y + h/2.
		cx1 = tx * w + cx
		cy1 = ty * h + cy
		w1 = math.exp(tw) * w
		h1 = math.exp(th) * h
		x1 = cx1 - w1/2.
		y1 = cy1 - h1/2.
		x1 = int(round(x1))
		y1 = int(round(y1))
		w1 = int(round(w1))
		h1 = int(round(h1))

		return x1, y1, w1, h1

	except ValueError:
		return x, y, w, h
	except OverflowError:
		return x, y, w, h
	except Exception as e:
		print(e)
		return x, y, w, h

# %%
def rpn_to_roi(rpn_layer, regr_layer, C, dim_ordering, use_regr=True, max_boxes=300,overlap_thresh=0.9):
	"""Convert rpn layer to roi bboxes

	Args: (num_anchors = 9)
		rpn_layer: output layer for rpn classification 
			shape (1, feature_map.height, feature_map.width, num_anchors)
			Might be (1, 18, 25, 9) if resized image is 400 width and 300
		regr_layer: output layer for rpn regression
			shape (1, feature_map.height, feature_map.width, num_anchors)
			Might be (1, 18, 25, 36) if resized image is 400 width and 300
		C: config
		use_regr: Wether to use bboxes regression in rpn
		max_boxes: max bboxes number for non-max-suppression (NMS)
		overlap_thresh: If iou in NMS is larger than this threshold, drop the box

	Returns:
		result: boxes from non-max-suppression (shape=(300, 4))
			boxes: coordinates for bboxes (on the feature map)
	"""
	regr_layer = regr_layer / C.std_scaling

	anchor_sizes = C.anchor_box_scales   # (3 in here)
	anchor_ratios = C.anchor_box_ratios  # (3 in here)

	assert rpn_layer.shape[0] == 1

	(rows, cols) = rpn_layer.shape[1:3]

	curr_layer = 0

	# A.shape = (4, feature_map.height, feature_map.width, num_anchors) 
	# Might be (4, 18, 25, 9) if resized image is 400 width and 300
	# A is the coordinates for 9 anchors for every point in the feature map 
	# => all 18x25x9=4050 anchors cooridnates
	A = np.zeros((4, rpn_layer.shape[1], rpn_layer.shape[2], rpn_layer.shape[3]))

	for anchor_size in anchor_sizes:
		for anchor_ratio in anchor_ratios:
			# anchor_x = (128 * 1) / 16 = 8  => width of current anchor
			# anchor_y = (128 * 2) / 16 = 16 => height of current anchor
			anchor_x = (anchor_size * anchor_ratio[0])/C.rpn_stride
			anchor_y = (anchor_size * anchor_ratio[1])/C.rpn_stride
			
			# curr_layer: 0~8 (9 anchors)
			# the Kth anchor of all position in the feature map (9th in total)
			regr = regr_layer[0, :, :, 4 * curr_layer:4 * curr_layer + 4] # shape => (18, 25, 4)
			regr = np.transpose(regr, (2, 0, 1)) # shape => (4, 18, 25)

			# Create 18x25 mesh grid
			# For every point in x, there are all the y points and vice versa
			# X.shape = (18, 25)
			# Y.shape = (18, 25)
			X, Y = np.meshgrid(np.arange(cols),np. arange(rows))

			# Calculate anchor position and size for each feature map point
			A[0, :, :, curr_layer] = X - anchor_x/2 # Top left x coordinate
			A[1, :, :, curr_layer] = Y - anchor_y/2 # Top left y coordinate
			A[2, :, :, curr_layer] = anchor_x       # width of current anchor
			A[3, :, :, curr_layer] = anchor_y       # height of current anchor

			# Apply regression to x, y, w and h if there is rpn regression layer
			if use_regr:
				A[:, :, :, curr_layer] = apply_regr_np(A[:, :, :, curr_layer], regr)

			# Avoid width and height exceeding 1
			A[2, :, :, curr_layer] = np.maximum(1, A[2, :, :, curr_layer])
			A[3, :, :, curr_layer] = np.maximum(1, A[3, :, :, curr_layer])

			# Convert (x, y , w, h) to (x1, y1, x2, y2)
			# x1, y1 is top left coordinate
			# x2, y2 is bottom right coordinate
			A[2, :, :, curr_layer] += A[0, :, :, curr_layer]
			A[3, :, :, curr_layer] += A[1, :, :, curr_layer]

			# Avoid bboxes drawn outside the feature map
			A[0, :, :, curr_layer] = np.maximum(0, A[0, :, :, curr_layer])
			A[1, :, :, curr_layer] = np.maximum(0, A[1, :, :, curr_layer])
			A[2, :, :, curr_layer] = np.minimum(cols-1, A[2, :, :, curr_layer])
			A[3, :, :, curr_layer] = np.minimum(rows-1, A[3, :, :, curr_layer])

			curr_layer += 1

	all_boxes = np.reshape(A.transpose((0, 3, 1, 2)), (4, -1)).transpose((1, 0))  # shape=(4050, 4)
	all_probs = rpn_layer.transpose((0, 3, 1, 2)).reshape((-1))                   # shape=(4050,)

	x1 = all_boxes[:, 0]
	y1 = all_boxes[:, 1]
	x2 = all_boxes[:, 2]
	y2 = all_boxes[:, 3]

	# Find out the bboxes which is illegal and delete them from bboxes list
	idxs = np.where((x1 - x2 >= 0) | (y1 - y2 >= 0))

	all_boxes = np.delete(all_boxes, idxs, 0)
	all_probs = np.delete(all_probs, idxs, 0)

	# Apply non_max_suppression
	# Only extract the bboxes. Don't need rpn probs in the later process
	result = non_max_suppression_fast(all_boxes, all_probs, overlap_thresh=overlap_thresh, max_boxes=max_boxes)[0]

	return result

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
base_path = 'drive/My Drive/FasterRCNN'

test_path = 'drive/My Drive/FasterRCNN/test2020.txt' # Test data (annotation file)

test_base_path = 'drive/My Drive/FasterRCNN/dataset/test2020' # Directory to save the test images

config_output_filename = os.path.join(base_path, 'model_vgg_config2020.pickle')

# %%
with open(config_output_filename, 'rb') as f_in:
	C = pickle.load(f_in)

# turn off any data augmentation at test time
C.use_horizontal_flips = False
C.use_vertical_flips = False
C.rot_90 = False

# %%
# Load the records
record_df = pd.read_csv(C.record_path)

r_epochs = len(record_df)

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(np.arange(0, r_epochs), record_df['mean_overlapping_bboxes'], 'r')
plt.title('mean_overlapping_bboxes')

plt.subplot(1,2,2)
plt.plot(np.arange(0, r_epochs), record_df['class_acc'], 'r')
plt.title('class_acc')

plt.show()

plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.plot(np.arange(0, r_epochs), record_df['loss_rpn_cls'], 'r')
plt.title('loss_rpn_cls')

plt.subplot(1,2,2)
plt.plot(np.arange(0, r_epochs), record_df['loss_rpn_regr'], 'r')
plt.title('loss_rpn_regr')
plt.show()
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(np.arange(0, r_epochs), record_df['loss_class_cls'], 'r')
plt.title('loss_class_cls')

plt.subplot(1,2,2)
plt.plot(np.arange(0, r_epochs), record_df['loss_class_regr'], 'r')
plt.title('loss_class_regr')
plt.show()
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(np.arange(0, r_epochs), record_df['curr_loss'], 'r')
plt.title('total_loss')

plt.subplot(1,2,2)
plt.plot(np.arange(0, r_epochs), record_df['elapsed_time'], 'r')
plt.title('elapsed_time')

plt.show()

# %% [markdown]
# # Test

# %%
def format_img_size(img, C):
	""" formats the image size based on config """
	img_min_side = float(C.im_size)
	(height,width,_) = img.shape
		
	if width <= height:
		ratio = img_min_side/width
		new_height = int(ratio * height)
		new_width = int(img_min_side)
	else:
		ratio = img_min_side/height
		new_width = int(ratio * width)
		new_height = int(img_min_side)
	img = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_CUBIC)
	return img, ratio	

def format_img_channels(img, C):
	""" formats the image channels based on config """
	img = img[:, :, (2, 1, 0)]
	img = img.astype(np.float32)
	img[:, :, 0] -= C.img_channel_mean[0]
	img[:, :, 1] -= C.img_channel_mean[1]
	img[:, :, 2] -= C.img_channel_mean[2]
	img /= C.img_scaling_factor
	img = np.transpose(img, (2, 0, 1))
	img = np.expand_dims(img, axis=0)
	return img

def format_img(img, C):
	""" formats an image for model prediction based on config """
	img, ratio = format_img_size(img, C)
	img = format_img_channels(img, C)
	return img, ratio

# Method to transform the coordinates of the bounding box to its original size
def get_real_coordinates(ratio, x1, y1, x2, y2):

	real_x1 = int(round(x1 // ratio))
	real_y1 = int(round(y1 // ratio))
	real_x2 = int(round(x2 // ratio))
	real_y2 = int(round(y2 // ratio))

	return (real_x1, real_y1, real_x2 ,real_y2)

# %%
num_features = 512

input_shape_img = (None, None, 3)
input_shape_features = (None, None, num_features)

img_input = Input(shape=input_shape_img)
roi_input = Input(shape=(C.num_rois, 4))
feature_map_input = Input(shape=input_shape_features)

# define the base network (VGG here, can be Resnet50, Inception, etc)
shared_layers = nn_base(img_input, trainable=True)

# define the RPN, built on the base layers
num_anchors = len(C.anchor_box_scales) * len(C.anchor_box_ratios)
rpn_layers = rpn_layer(shared_layers, num_anchors)

classifier = classifier_layer(feature_map_input, roi_input, C.num_rois, nb_classes=len(C.class_mapping))

model_rpn = Model(img_input, rpn_layers)
model_classifier_only = Model([feature_map_input, roi_input], classifier)

model_classifier = Model([feature_map_input, roi_input], classifier)

print('Loading weights from {}'.format(C.model_path))
model_rpn.load_weights(C.model_path, by_name=True)
model_classifier.load_weights(C.model_path, by_name=True)

model_rpn.compile(optimizer='sgd', loss='mse')
model_classifier.compile(optimizer='sgd', loss='mse')
# Out:
# Loading weights from drive/My Drive/FasterRCNN/model/model_frcnn_vgg2020.hdf5

# %%
# Switch key value for class mapping
class_mapping = C.class_mapping
class_mapping = {v: k for k, v in class_mapping.items()}
print(class_mapping)
class_to_color = {class_mapping[v]: np.random.randint(0, 255, 3) for v in class_mapping}
# Out:
# {0: 'Tortuga', 1: 'Pez', 2: 'bg'}

# %%
test_imgs = os.listdir(test_base_path)

imgs_path = []
for i in range(12):
	idx = np.random.randint(len(test_imgs))
	imgs_path.append(test_imgs[idx])

all_imgs = []

classes = {}

# %%
# If the box classification value is less than this, we ignore this box
bbox_threshold = 0.7

for idx, img_name in enumerate(imgs_path):
    if not img_name.lower().endswith(('.bmp', '.jpeg', '.jpg', '.png', '.tif', '.tiff')):
        continue
    print(img_name)
    st = time.time()
    filepath = os.path.join(test_base_path, img_name)

    img = cv2.imread(filepath)

    X, ratio = format_img(img, C)
    
    X = np.transpose(X, (0, 2, 3, 1))

    # get output layer Y1, Y2 from the RPN and the feature maps F
    # Y1: y_rpn_cls
    # Y2: y_rpn_regr
    [Y1, Y2, F] = model_rpn.predict(X)

    # Get bboxes by applying NMS 
    # R.shape = (300, 4)
    #R = rpn_to_roi(Y1, Y2, C, K.image_dim_ordering(), overlap_thresh=0.7)
    R = rpn_to_roi(Y1, Y2, C, K.image_data_format(), overlap_thresh=0.7)

    # convert from (x1,y1,x2,y2) to (x,y,w,h)
    R[:, 2] -= R[:, 0]
    R[:, 3] -= R[:, 1]

    # apply the spatial pyramid pooling to the proposed regions
    bboxes = {}
    probs = {}

    for jk in range(R.shape[0]//C.num_rois + 1):
        ROIs = np.expand_dims(R[C.num_rois*jk:C.num_rois*(jk+1), :], axis=0)
        if ROIs.shape[1] == 0:
            break

        if jk == R.shape[0]//C.num_rois:
            #pad R
            curr_shape = ROIs.shape
            target_shape = (curr_shape[0],C.num_rois,curr_shape[2])
            ROIs_padded = np.zeros(target_shape).astype(ROIs.dtype)
            ROIs_padded[:, :curr_shape[1], :] = ROIs
            ROIs_padded[0, curr_shape[1]:, :] = ROIs[0, 0, :]
            ROIs = ROIs_padded

        [P_cls, P_regr] = model_classifier_only.predict([F, ROIs])

        # Calculate bboxes coordinates on resized image
        for ii in range(P_cls.shape[1]):
            # Ignore 'bg' class
            if np.max(P_cls[0, ii, :]) < bbox_threshold or np.argmax(P_cls[0, ii, :]) == (P_cls.shape[2] - 1):
                continue

            cls_name = class_mapping[np.argmax(P_cls[0, ii, :])]

            if cls_name not in bboxes:
                bboxes[cls_name] = []
                probs[cls_name] = []

            (x, y, w, h) = ROIs[0, ii, :]

            cls_num = np.argmax(P_cls[0, ii, :])
            try:
                (tx, ty, tw, th) = P_regr[0, ii, 4*cls_num:4*(cls_num+1)]
                tx /= C.classifier_regr_std[0]
                ty /= C.classifier_regr_std[1]
                tw /= C.classifier_regr_std[2]
                th /= C.classifier_regr_std[3]
                x, y, w, h = apply_regr(x, y, w, h, tx, ty, tw, th)
            except:
                pass
            bboxes[cls_name].append([C.rpn_stride*x, C.rpn_stride*y, C.rpn_stride*(x+w), C.rpn_stride*(y+h)])
            probs[cls_name].append(np.max(P_cls[0, ii, :]))

    all_dets = []

    for key in bboxes:
        bbox = np.array(bboxes[key])

        new_boxes, new_probs = non_max_suppression_fast(bbox, np.array(probs[key]), overlap_thresh=0.2)
        for jk in range(new_boxes.shape[0]):
            (x1, y1, x2, y2) = new_boxes[jk,:]

            # Calculate real coordinates on original image
            (real_x1, real_y1, real_x2, real_y2) = get_real_coordinates(ratio, x1, y1, x2, y2)

            cv2.rectangle(img,(real_x1, real_y1), (real_x2, real_y2), (int(class_to_color[key][0]), int(class_to_color[key][1]), int(class_to_color[key][2])),4)

            textLabel = '{}: {}'.format(key,int(100*new_probs[jk]))
            all_dets.append((key,100*new_probs[jk]))

            (retval,baseLine) = cv2.getTextSize(textLabel,cv2.FONT_HERSHEY_COMPLEX,1,1)
            textOrg = (real_x1, real_y1-0)

            cv2.rectangle(img, (textOrg[0] - 5, textOrg[1]+baseLine - 5), (textOrg[0]+retval[0] + 5, textOrg[1]-retval[1] - 5), (0, 0, 0), 1)
            cv2.rectangle(img, (textOrg[0] - 5,textOrg[1]+baseLine - 5), (textOrg[0]+retval[0] + 5, textOrg[1]-retval[1] - 5), (255, 255, 255), -1)
            cv2.putText(img, textLabel, textOrg, cv2.FONT_HERSHEY_DUPLEX, 1, (0, 0, 0), 1)

    print('Elapsed time = {}'.format(time.time() - st))
    print(all_dets)
    plt.figure(figsize=(10,10))
  
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #### Measure mAP

# %%
def get_map(pred, gt, f):
	T = {}
	P = {}
	fx, fy = f

	for bbox in gt:
		bbox['bbox_matched'] = False

	pred_probs = np.array([s['prob'] for s in pred])
	box_idx_sorted_by_prob = np.argsort(pred_probs)[::-1]

	for box_idx in box_idx_sorted_by_prob:
		pred_box = pred[box_idx]
		pred_class = pred_box['class']
		pred_x1 = pred_box['x1']
		pred_x2 = pred_box['x2']
		pred_y1 = pred_box['y1']
		pred_y2 = pred_box['y2']
		pred_prob = pred_box['prob']
		if pred_class not in P:
			P[pred_class] = []
			T[pred_class] = []
		P[pred_class].append(pred_prob)
		found_match = False

		for gt_box in gt:
			gt_class = gt_box['class']
			gt_x1 = gt_box['x1']/fx
			gt_x2 = gt_box['x2']/fx
			gt_y1 = gt_box['y1']/fy
			gt_y2 = gt_box['y2']/fy
			gt_seen = gt_box['bbox_matched']
			if gt_class != pred_class:
				continue
			if gt_seen:
				continue
			iou_map = iou((pred_x1, pred_y1, pred_x2, pred_y2), (gt_x1, gt_y1, gt_x2, gt_y2))
			if iou_map >= 0.5:
				found_match = True
				gt_box['bbox_matched'] = True
				break
			else:
				continue

		T[pred_class].append(int(found_match))

	for gt_box in gt:
		if not gt_box['bbox_matched']:# and not gt_box['difficult']:
			if gt_box['class'] not in P:
				P[gt_box['class']] = []
				T[gt_box['class']] = []

			T[gt_box['class']].append(1)
			P[gt_box['class']].append(0)

	#import pdb
	#pdb.set_trace()
	return T, P

# %%
def format_img_map(img, C):
	"""Format image for mAP. Resize original image to C.im_size (300 in here)

	Args:
		img: cv2 image
		C: config

	Returns:
		img: Scaled and normalized image with expanding dimension
		fx: ratio for width scaling
		fy: ratio for height scaling
	"""

	img_min_side = float(C.im_size)
	(height,width,_) = img.shape
	
	if width <= height:
		f = img_min_side/width
		new_height = int(f * height)
		new_width = int(img_min_side)
	else:
		f = img_min_side/height
		new_width = int(f * width)
		new_height = int(img_min_side)
	fx = width/float(new_width)
	fy = height/float(new_height)
	img = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_CUBIC)
	# Change image channel from BGR to RGB
	img = img[:, :, (2, 1, 0)]
	img = img.astype(np.float32)
	img[:, :, 0] -= C.img_channel_mean[0]
	img[:, :, 1] -= C.img_channel_mean[1]
	img[:, :, 2] -= C.img_channel_mean[2]
	img /= C.img_scaling_factor
	# Change img shape from (height, width, channel) to (channel, height, width)
	img = np.transpose(img, (2, 0, 1))
	# Expand one dimension at axis 0
	# img shape becames (1, channel, height, width)
	img = np.expand_dims(img, axis=0)
	return img, fx, fy

# %%
print(class_mapping)
# Out:
# {0: 'Tortuga', 1: 'Pez', 2: 'bg'}

# %%
# This might takes a while to parser the data
test_imgs, _, _ = get_data(test_path)
# Out:
# Parsing annotation files
# idx=651

# %%
T = {}
P = {}
mAPs = []
for idx, img_data in enumerate(test_imgs):
    print('{}/{}'.format(idx,len(test_imgs)))
    st = time.time()
    filepath = img_data['filepath']

    img = cv2.imread(filepath)

    X, fx, fy = format_img_map(img, C)

    # Change X (img) shape from (1, channel, height, width) to (1, height, width, channel)
    X = np.transpose(X, (0, 2, 3, 1))

    # get the feature maps and output from the RPN
    [Y1, Y2, F] = model_rpn.predict(X)


    #R = rpn_to_roi(Y1, Y2, C, K.image_dim_ordering(), overlap_thresh=0.7)
    R = rpn_to_roi(Y1, Y2, C, K.image_data_format(), overlap_thresh=0.7)
    
    # convert from (x1,y1,x2,y2) to (x,y,w,h)
    R[:, 2] -= R[:, 0]
    R[:, 3] -= R[:, 1]

    # apply the spatial pyramid pooling to the proposed regions
    bboxes = {}
    probs = {}

    for jk in range(R.shape[0] // C.num_rois + 1):
        ROIs = np.expand_dims(R[C.num_rois * jk:C.num_rois * (jk + 1), :], axis=0)
        if ROIs.shape[1] == 0:
            break

        if jk == R.shape[0] // C.num_rois:
            # pad R
            curr_shape = ROIs.shape
            target_shape = (curr_shape[0], C.num_rois, curr_shape[2])
            ROIs_padded = np.zeros(target_shape).astype(ROIs.dtype)
            ROIs_padded[:, :curr_shape[1], :] = ROIs
            ROIs_padded[0, curr_shape[1]:, :] = ROIs[0, 0, :]
            ROIs = ROIs_padded

        [P_cls, P_regr] = model_classifier_only.predict([F, ROIs])

        # Calculate all classes' bboxes coordinates on resized image (300, 400)
        # Drop 'bg' classes bboxes
        for ii in range(P_cls.shape[1]):

            # If class name is 'bg', continue
            if np.argmax(P_cls[0, ii, :]) == (P_cls.shape[2] - 1):
                continue

            # Get class name
            cls_name = class_mapping[np.argmax(P_cls[0, ii, :])]

            if cls_name not in bboxes:
                bboxes[cls_name] = []
                probs[cls_name] = []

            (x, y, w, h) = ROIs[0, ii, :]

            cls_num = np.argmax(P_cls[0, ii, :])
            try:
                (tx, ty, tw, th) = P_regr[0, ii, 4 * cls_num:4 * (cls_num + 1)]
                tx /= C.classifier_regr_std[0]
                ty /= C.classifier_regr_std[1]
                tw /= C.classifier_regr_std[2]
                th /= C.classifier_regr_std[3]
                x, y, w, h = roi_helpers.apply_regr(x, y, w, h, tx, ty, tw, th)
            except:
                pass
            bboxes[cls_name].append([16 * x, 16 * y, 16 * (x + w), 16 * (y + h)])
            probs[cls_name].append(np.max(P_cls[0, ii, :]))

    all_dets = []

    for key in bboxes:
        bbox = np.array(bboxes[key])

        # Apply non-max-suppression on final bboxes to get the output bounding boxe
        new_boxes, new_probs = non_max_suppression_fast(bbox, np.array(probs[key]), overlap_thresh=0.5)
        for jk in range(new_boxes.shape[0]):
            (x1, y1, x2, y2) = new_boxes[jk, :]
            det = {'x1': x1, 'x2': x2, 'y1': y1, 'y2': y2, 'class': key, 'prob': new_probs[jk]}
            all_dets.append(det)


    print('Elapsed time = {}'.format(time.time() - st))
    t, p = get_map(all_dets, img_data['bboxes'], (fx, fy))
    for key in t.keys():
        if key not in T:
            T[key] = []
            P[key] = []
        T[key].extend(t[key])
        P[key].extend(p[key])
    all_aps = []
    for key in T.keys():
        ap = average_precision_score(T[key], P[key])
        print('{} AP: {}'.format(key, ap))
        all_aps.append(ap)
    print('mAP = {}'.format(np.mean(np.array(all_aps))))
    mAPs.append(np.mean(np.array(all_aps)))
    #print(T)
    #print(P)
    
print()
print('mean average precision:', np.mean(np.array(mAPs)))
# Out:
# 0/234
# Elapsed time = 5.116287469863892
# Tortuga AP: 1.0
# mAP = 1.0
# 1/234
# Elapsed time = 6.5427281856536865
# Tortuga AP: 0.7
# Pez AP: nan
# mAP = nan
# 2/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.233655214309692
# Tortuga AP: 0.8611111111111112
# Pez AP: nan
# mAP = nan
# 3/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.991748571395874
# Tortuga AP: 0.8769230769230769
# Pez AP: nan
# mAP = nan
# 4/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.161007881164551
# Tortuga AP: 0.8347222222222223
# Pez AP: nan
# mAP = nan
# 5/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.587395668029785
# Tortuga AP: 0.8655567490153955
# Pez AP: nan
# mAP = nan
# 6/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.659183502197266
# Tortuga AP: 0.864162784679089
# Pez AP: nan
# mAP = nan
# 7/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.60134744644165
# Tortuga AP: 0.8753663003663004
# Pez AP: nan
# mAP = nan
# 8/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.526549577713013
# Tortuga AP: 0.8847222222222221
# Pez AP: nan
# mAP = nan
# 9/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 4.874573707580566
# Tortuga AP: 0.8803391053391054
# Pez AP: nan
# mAP = nan
# 10/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.023904085159302
# Tortuga AP: 0.8942760942760942
# Pez AP: nan
# mAP = nan
# 11/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.049038410186768
# Tortuga AP: 0.9006335133368923
# Pez AP: nan
# mAP = nan
# 12/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.585728406906128
# Tortuga AP: 0.8885411740453757
# Pez AP: nan
# mAP = nan
# 13/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.0469069480896
# Tortuga AP: 0.8861110476536973
# Pez AP: nan
# mAP = nan
# 14/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 4.926124572753906
# Tortuga AP: 0.8898653429903429
# Pez AP: nan
# mAP = nan
# 15/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.09652042388916
# Tortuga AP: 0.8943777839139662
# Pez AP: nan
# mAP = nan
# 16/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.015761375427246
# Tortuga AP: 0.902602967459684
# Pez AP: nan
# mAP = nan
# 17/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.313469886779785
# Tortuga AP: 0.8943799617395873
# Pez AP: nan
# mAP = nan
# 18/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.334158658981323
# Tortuga AP: 0.8712325592327931
# Pez AP: nan
# mAP = nan
# 19/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.034491777420044
# Tortuga AP: 0.7884337561673841
# Pez AP: nan
# mAP = nan
# 20/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.387341499328613
# Tortuga AP: 0.7880731562558134
# Pez AP: nan
# mAP = nan
# 21/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.803626775741577
# Tortuga AP: 0.7982165238732264
# Pez AP: nan
# mAP = nan
# 22/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.107102632522583
# Tortuga AP: 0.788520692793421
# Pez AP: nan
# mAP = nan
# 23/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.406329154968262
# Tortuga AP: 0.7667058603242878
# Pez AP: nan
# mAP = nan
# 24/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.1580095291137695
# Tortuga AP: 0.7762912302216274
# Pez AP: nan
# mAP = nan
# 25/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.135061502456665
# Tortuga AP: 0.7837128284361029
# Pez AP: nan
# mAP = nan
# 26/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.168356418609619
# Tortuga AP: 0.7851425665658486
# Pez AP: nan
# mAP = nan
# 27/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.690912246704102
# Tortuga AP: 0.7908026072946702
# Pez AP: nan
# mAP = nan
# 28/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.213481187820435
# Tortuga AP: 0.7656019145559867
# Pez AP: nan
# mAP = nan
# 29/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.466104507446289
# Tortuga AP: 0.7701483191937922
# Pez AP: nan
# mAP = nan
# 30/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.22659707069397
# Tortuga AP: 0.777323520266606
# Pez AP: nan
# mAP = nan
# 31/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.052231311798096
# Tortuga AP: 0.7707806258797484
# Pez AP: nan
# mAP = nan
# 32/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.243118524551392
# Tortuga AP: 0.7707787530224878
# Pez AP: nan
# mAP = nan
# 33/234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.054847955703735
# Tortuga AP: 0.7757281639976372
# Pez AP: 0.08396624472573841
# mAP = 0.42984720436168783
# 34/234
# Elapsed time = 6.402158498764038
# Tortuga AP: 0.7790333538266617
# Pez AP: 0.08396624472573841
# mAP = 0.4314997992762001
# 35/234
# Elapsed time = 5.003768444061279
# Tortuga AP: 0.7811968615121241
# Pez AP: 0.08396624472573841
# mAP = 0.43258155311893126
# 36/234
# Elapsed time = 5.113487482070923
# Tortuga AP: 0.7852063807991982
# Pez AP: 0.08333333333333334
# mAP = 0.4342698570662658
# 37/234
# Elapsed time = 5.373274564743042
# Tortuga AP: 0.790354306072297
# Pez AP: 0.08333333333333334
# mAP = 0.43684381970281516
# 38/234
# Elapsed time = 5.268655776977539
# Tortuga AP: 0.7945266047823343
# Pez AP: 0.08333333333333334
# mAP = 0.4389299690578338
# 39/234
# Elapsed time = 5.085346460342407
# Tortuga AP: 0.7946548442679182
# Pez AP: 0.08333333333333334
# mAP = 0.4389940888006258
# 40/234
# Elapsed time = 5.442418813705444
# Tortuga AP: 0.8001085014580287
# Pez AP: 0.08211382113821139
# mAP = 0.44111116129812006
# 41/234
# Elapsed time = 5.179302453994751
# Tortuga AP: 0.8028334034875599
# Pez AP: 0.08152610441767069
# mAP = 0.44217975395261533
# 42/234
# Elapsed time = 5.162978410720825
# Tortuga AP: 0.8061995249467386
# Pez AP: 0.0793103448275862
# mAP = 0.44275493488716244
# 43/234
# Elapsed time = 5.344754695892334
# Tortuga AP: 0.8059036385752033
# Pez AP: 0.0787878787878788
# mAP = 0.442345758681541
# 44/234
# Elapsed time = 5.349411249160767
# Tortuga AP: 0.8095498538888176
# Pez AP: 0.0787878787878788
# mAP = 0.4441688663383482
# 45/234
# Elapsed time = 5.263248443603516
# Tortuga AP: 0.8119934914477661
# Pez AP: 0.0787878787878788
# mAP = 0.4453906851178224
# 46/234
# Elapsed time = 5.321738004684448
# Tortuga AP: 0.8066062427284206
# Pez AP: 0.07827715355805243
# mAP = 0.44244169814323653
# 47/234
# Elapsed time = 5.025841236114502
# Tortuga AP: 0.8108292489409585
# Pez AP: 0.07827715355805243
# mAP = 0.4445532012495055
# 48/234
# Elapsed time = 5.967339038848877
# Tortuga AP: 0.8151279978831427
# Pez AP: 0.07827715355805243
# mAP = 0.44670257572059757
# 49/234
# Elapsed time = 6.043483734130859
# Tortuga AP: 0.8195912082427869
# Pez AP: 0.07827715355805243
# mAP = 0.44893418090041964
# 50/234
# Elapsed time = 5.096038818359375
# Tortuga AP: 0.8236764500333068
# Pez AP: 0.07777777777777778
# mAP = 0.4507271139055423
# 51/234
# Elapsed time = 5.387765645980835
# Tortuga AP: 0.8199591926546271
# Pez AP: 0.07728937728937729
# mAP = 0.44862428497200224
# 52/234
# Elapsed time = 5.081964731216431
# Tortuga AP: 0.8236940845583477
# Pez AP: 0.07728937728937729
# mAP = 0.4504917309238625
# 53/234
# Elapsed time = 4.9512574672698975
# Tortuga AP: 0.8224014278824112
# Pez AP: 0.07634408602150539
# mAP = 0.44937275695195833
# 54/234
# Elapsed time = 4.965226888656616
# Tortuga AP: 0.8254597301603663
# Pez AP: 0.07333333333333333
# mAP = 0.44939653174684985
# 55/234
# Elapsed time = 4.952200651168823
# Tortuga AP: 0.8291918858483418
# Pez AP: 0.06703296703296703
# mAP = 0.4481124264406544
# 56/234
# Elapsed time = 5.510712385177612
# Tortuga AP: 0.8320774501406933
# Pez AP: 0.0656084656084656
# mAP = 0.44884295787457945
# 57/234
# Elapsed time = 5.29500675201416
# Tortuga AP: 0.83271509652478
# Pez AP: 0.0656084656084656
# mAP = 0.4491617810666228
# 58/234
# Elapsed time = 5.073847055435181
# Tortuga AP: 0.8255887262019795
# Pez AP: 0.0656084656084656
# mAP = 0.44559859590522255
# 59/234
# Elapsed time = 6.080437898635864
# Tortuga AP: 0.8255887262019795
# Pez AP: 0.1574074074074074
# mAP = 0.4914980668046935
# 60/234
# Elapsed time = 5.391122579574585
# Tortuga AP: 0.8255887262019795
# Pez AP: 0.2205992291187293
# mAP = 0.5230939776603545
# 61/234
# Elapsed time = 5.94028377532959
# Tortuga AP: 0.8255887262019795
# Pez AP: 0.26225509404388714
# mAP = 0.5439219101229333
# 62/234
# Elapsed time = 5.195112943649292
# Tortuga AP: 0.8255887262019795
# Pez AP: 0.2987494102045185
# mAP = 0.562169068203249
# 63/234
# Elapsed time = 5.144410610198975
# Tortuga AP: 0.8255887262019795
# Pez AP: 0.32874884360697243
# mAP = 0.577168784904476
# 64/234
# Elapsed time = 5.720909833908081
# Tortuga AP: 0.8255887262019795
# Pez AP: 0.39376965133278596
# mAP = 0.6096791887673827
# 65/234
# Elapsed time = 5.527831077575684
# Tortuga AP: 0.8255887262019795
# Pez AP: 0.4080285614768374
# mAP = 0.6168086438394085
# 66/234
# Elapsed time = 5.558907508850098
# Tortuga AP: 0.8255887262019795
# Pez AP: 0.43244126652445825
# mAP = 0.6290149963632189
# 67/234
# Elapsed time = 5.874438047409058
# Tortuga AP: 0.8255887262019795
# Pez AP: 0.4527399023613513
# mAP = 0.6391643142816654
# 68/234
# Elapsed time = 5.476092576980591
# Tortuga AP: 0.825520152534268
# Pez AP: 0.46774491547099467
# mAP = 0.6466325340026313
# 69/234
# Elapsed time = 5.125473499298096
# Tortuga AP: 0.825520152534268
# Pez AP: 0.43516137669788235
# mAP = 0.6303407646160752
# 70/234
# Elapsed time = 5.08025050163269
# Tortuga AP: 0.8254425908698224
# Pez AP: 0.4311419285872923
# mAP = 0.6282922597285574
# 71/234
# Elapsed time = 5.005101442337036
# Tortuga AP: 0.8249439717314879
# Pez AP: 0.4257741612148147
# mAP = 0.6253590664731513
# 72/234
# Elapsed time = 4.939342975616455
# Tortuga AP: 0.8248524403185402
# Pez AP: 0.4305602501029797
# mAP = 0.62770634521076
# 73/234
# Elapsed time = 5.0233893394470215
# Tortuga AP: 0.8245727011846141
# Pez AP: 0.42148680037126574
# mAP = 0.6230297507779399
# 74/234
# Elapsed time = 5.481940507888794
# Tortuga AP: 0.8245727011846141
# Pez AP: 0.42629960593885413
# mAP = 0.6254361535617341
# 75/234
# Elapsed time = 5.060266494750977
# Tortuga AP: 0.8245727011846141
# Pez AP: 0.4372186904080362
# mAP = 0.6308956957963252
# 76/234
# Elapsed time = 5.125997066497803
# Tortuga AP: 0.8244581176434354
# Pez AP: 0.4500936657472275
# mAP = 0.6372758916953314
# 77/234
# Elapsed time = 5.574915885925293
# Tortuga AP: 0.8244581176434354
# Pez AP: 0.49583725944959395
# mAP = 0.6601476885465146
# 78/234
# Elapsed time = 5.08967399597168
# Tortuga AP: 0.8244581176434354
# Pez AP: 0.41737523635794394
# mAP = 0.6209166770006896
# 79/234
# Elapsed time = 4.947565793991089
# Tortuga AP: 0.8243860716180925
# Pez AP: 0.4235564651047093
# mAP = 0.6239712683614009
# 80/234
# Elapsed time = 4.981405735015869
# Tortuga AP: 0.8243860716180925
# Pez AP: 0.43368981617261326
# mAP = 0.6290379438953528
# 81/234
# Elapsed time = 5.084116220474243
# Tortuga AP: 0.8243860716180925
# Pez AP: 0.43979769242464717
# mAP = 0.6320918820213699
# 82/234
# Elapsed time = 5.047948360443115
# Tortuga AP: 0.8243144584536523
# Pez AP: 0.4210549328912577
# mAP = 0.622684695672455
# 83/234
# Elapsed time = 5.190588474273682
# Tortuga AP: 0.8242432742604677
# Pez AP: 0.42378746841459686
# mAP = 0.6240153713375323
# 84/234
# Elapsed time = 6.241694211959839
# Tortuga AP: 0.8242432742604677
# Pez AP: 0.43977955312609673
# mAP = 0.6320114136932822
# 85/234
# Elapsed time = 5.112538814544678
# Tortuga AP: 0.8242432742604677
# Pez AP: 0.44230880254771143
# mAP = 0.6332760384040896
# 86/234
# Elapsed time = 5.113898277282715
# Tortuga AP: 0.8241725151953577
# Pez AP: 0.43138062537998656
# mAP = 0.6277765702876721
# 87/234
# Elapsed time = 6.12218713760376
# Tortuga AP: 0.8241725151953577
# Pez AP: 0.4334153884145345
# mAP = 0.6287939518049461
# 88/234
# Elapsed time = 5.708905220031738
# Tortuga AP: 0.8241725151953577
# Pez AP: 0.4379981384966903
# mAP = 0.631085326846024
# 89/234
# Elapsed time = 4.952719688415527
# Tortuga AP: 0.8241725151953577
# Pez AP: 0.4409708668522679
# mAP = 0.6325716910238128
# 90/234
# Elapsed time = 5.09061598777771
# Tortuga AP: 0.8241725151953577
# Pez AP: 0.4460114040291784
# mAP = 0.635091959612268
# 91/234
# Elapsed time = 5.760142803192139
# Tortuga AP: 0.8241725151953577
# Pez AP: 0.4396060087551862
# mAP = 0.631889261975272
# 92/234
# Elapsed time = 5.591013669967651
# Tortuga AP: 0.8241725151953577
# Pez AP: 0.44210332102309946
# mAP = 0.6331379181092286
# 93/234
# Elapsed time = 5.38434100151062
# Tortuga AP: 0.8241725151953577
# Pez AP: 0.4353876102952605
# mAP = 0.6297800627453092
# 94/234
# Elapsed time = 5.1018781661987305
# Tortuga AP: 0.8241021774609173
# Pez AP: 0.43855282674622953
# mAP = 0.6313275021035734
# 95/234
# Elapsed time = 5.722791433334351
# Tortuga AP: 0.8240322573048376
# Pez AP: 0.4422926348210403
# mAP = 0.633162446062939
# 96/234
# Elapsed time = 5.059269189834595
# Tortuga AP: 0.8240322573048376
# Pez AP: 0.43783445071523863
# mAP = 0.6309333540100381
# 97/234
# Elapsed time = 5.227730751037598
# Tortuga AP: 0.8240322573048376
# Pez AP: 0.4417382014425828
# mAP = 0.6328852293737102
# 98/234
# Elapsed time = 6.255857706069946
# Tortuga AP: 0.8240322573048376
# Pez AP: 0.44738465180971565
# mAP = 0.6357084545572766
# 99/234
# Elapsed time = 5.118621110916138
# Tortuga AP: 0.8240322573048376
# Pez AP: 0.4507443207548357
# mAP = 0.6373882890298367
# 100/234
# Elapsed time = 5.072246789932251
# Tortuga AP: 0.8240322573048376
# Pez AP: 0.45324612620336935
# mAP = 0.6386391917541034
# 101/234
# Elapsed time = 5.200650930404663
# Tortuga AP: 0.8240322573048376
# Pez AP: 0.45682929527582394
# mAP = 0.6404307762903307
# 102/234
# Elapsed time = 5.207428216934204
# Tortuga AP: 0.8240322573048376
# Pez AP: 0.45256003892224844
# mAP = 0.6382961481135431
# 103/234
# Elapsed time = 5.197169065475464
# Tortuga AP: 0.8240322573048376
# Pez AP: 0.44166348797366806
# mAP = 0.6328478726392528
# 104/234
# Elapsed time = 5.633028268814087
# Tortuga AP: 0.8240322573048376
# Pez AP: 0.44752130746768704
# mAP = 0.6357767823862623
# 105/234
# Elapsed time = 5.157313346862793
# Tortuga AP: 0.8240322573048376
# Pez AP: 0.45191185621245533
# mAP = 0.6379720567586464
# 106/234
# Elapsed time = 6.288347959518433
# Tortuga AP: 0.8240322573048376
# Pez AP: 0.45274666634507926
# mAP = 0.6383894618249585
# 107/234
# Elapsed time = 4.9379801750183105
# Tortuga AP: 0.8239210622064519
# Pez AP: 0.453661030271834
# mAP = 0.638791046239143
# 108/234
# Elapsed time = 5.063263416290283
# Tortuga AP: 0.8239210622064519
# Pez AP: 0.45643326775232945
# mAP = 0.6401771649793907
# 109/234
# Elapsed time = 10.084601640701294
# Tortuga AP: 0.8239210622064519
# Pez AP: 0.4596673212202349
# mAP = 0.6417941917133434
# 110/234
# Elapsed time = 8.04586911201477
# Tortuga AP: 0.8239210622064519
# Pez AP: 0.46137034353227546
# mAP = 0.6426457028693637
# 111/234
# Elapsed time = 4.993704319000244
# Tortuga AP: 0.8239210622064519
# Pez AP: 0.45729991222230026
# mAP = 0.6406104872143761
# 112/234
# Elapsed time = 5.824557065963745
# Tortuga AP: 0.8239210622064519
# Pez AP: 0.4613317586258908
# mAP = 0.6426264104161714
# 113/234
# Elapsed time = 9.987905502319336
# Tortuga AP: 0.8239210622064519
# Pez AP: 0.46325707695033025
# mAP = 0.643589069578391
# 114/234
# Elapsed time = 5.09276270866394
# Tortuga AP: 0.8238603299489471
# Pez AP: 0.46685473508659525
# mAP = 0.6453575325177712
# 115/234
# Elapsed time = 5.215816974639893
# Tortuga AP: 0.8238603299489471
# Pez AP: 0.46971507850781924
# mAP = 0.6467877042283832
# 116/234
# Elapsed time = 5.2265846729278564
# Tortuga AP: 0.8238603299489471
# Pez AP: 0.4718915343873634
# mAP = 0.6478759321681553
# 117/234
# Elapsed time = 5.066766977310181
# Tortuga AP: 0.8238603299489471
# Pez AP: 0.4755894090320928
# mAP = 0.64972486949052
# 118/234
# Elapsed time = 6.028536319732666
# Tortuga AP: 0.8238603299489471
# Pez AP: 0.4795029888005748
# mAP = 0.651681659374761
# 119/234
# Elapsed time = 8.84969973564148
# Tortuga AP: 0.8238603299489471
# Pez AP: 0.4819953303083141
# mAP = 0.6529278301286305
# 120/234
# Elapsed time = 10.220839500427246
# Tortuga AP: 0.8238603299489471
# Pez AP: 0.4851499557274711
# mAP = 0.6545051428382092
# 121/234
# Elapsed time = 6.289911508560181
# Tortuga AP: 0.8237915900706421
# Pez AP: 0.48884949952647083
# mAP = 0.6563205447985565
# 122/234
# Elapsed time = 9.464428186416626
# Tortuga AP: 0.8237915900706421
# Pez AP: 0.48210144998573573
# mAP = 0.6529465200281889
# 123/234
# Elapsed time = 5.099963903427124
# Tortuga AP: 0.8236042546051519
# Pez AP: 0.468662307451818
# mAP = 0.646133281028485
# 124/234
# Elapsed time = 5.515145540237427
# Tortuga AP: 0.8300159258655517
# Pez AP: 0.468662307451818
# mAP = 0.6493391166586848
# 125/234
# Elapsed time = 5.355138301849365
# Tortuga AP: 0.8301115099590234
# Pez AP: 0.468662307451818
# mAP = 0.6493869087054207
# 126/234
# Elapsed time = 5.5200324058532715
# Tortuga AP: 0.8325757812587833
# Pez AP: 0.468662307451818
# mAP = 0.6506190443553006
# 127/234
# Elapsed time = 5.250572681427002
# Tortuga AP: 0.8344574557573905
# Pez AP: 0.467919372985789
# mAP = 0.6511884143715898
# 128/234
# Elapsed time = 4.958222150802612
# Tortuga AP: 0.8366032161464645
# Pez AP: 0.467919372985789
# mAP = 0.6522612945661268
# 129/234
# Elapsed time = 6.089916706085205
# Tortuga AP: 0.8135843769806785
# Pez AP: 0.467919372985789
# mAP = 0.6407518749832337
# 130/234
# Elapsed time = 5.145338535308838
# Tortuga AP: 0.6993345106183539
# Pez AP: 0.467919372985789
# mAP = 0.5836269418020714
# 131/234
# Elapsed time = 5.160794258117676
# Tortuga AP: 0.7014105428596416
# Pez AP: 0.467919372985789
# mAP = 0.5846649579227152
# 132/234
# Elapsed time = 4.968529224395752
# Tortuga AP: 0.7036558129897691
# Pez AP: 0.467919372985789
# mAP = 0.585787592987779
# 133/234
# Elapsed time = 5.2315778732299805
# Tortuga AP: 0.7059429464787207
# Pez AP: 0.467919372985789
# mAP = 0.5869311597322548
# 134/234
# Elapsed time = 5.1386518478393555
# Tortuga AP: 0.7079185631362289
# Pez AP: 0.467919372985789
# mAP = 0.587918968061009
# 135/234
# Elapsed time = 5.481137037277222
# Tortuga AP: 0.7114580732232794
# Pez AP: 0.4665528179154195
# mAP = 0.5890054455693494
# 136/234
# Elapsed time = 5.184786796569824
# Tortuga AP: 0.7136345682461093
# Pez AP: 0.4665528179154195
# mAP = 0.5900936930807644
# 137/234
# Elapsed time = 5.278953552246094
# Tortuga AP: 0.7143372217915842
# Pez AP: 0.46556786406165207
# mAP = 0.5899525429266181
# 138/234
# Elapsed time = 5.935250520706177
# Tortuga AP: 0.7157499862581438
# Pez AP: 0.4652292803331871
# mAP = 0.5904896332956655
# 139/234
# Elapsed time = 5.340177059173584
# Tortuga AP: 0.718679980331487
# Pez AP: 0.4652292803331871
# mAP = 0.5919546303323371
# 140/234
# Elapsed time = 5.154581785202026
# Tortuga AP: 0.7224345074794993
# Pez AP: 0.4652292803331871
# mAP = 0.5938318939063432
# 141/234
# Elapsed time = 5.34944486618042
# Tortuga AP: 0.7255931686613996
# Pez AP: 0.4652292803331871
# mAP = 0.5954112244972933
# 142/234
# Elapsed time = 5.508483409881592
# Tortuga AP: 0.7317886787907443
# Pez AP: 0.4652292803331871
# mAP = 0.5985089795619657
# 143/234
# Elapsed time = 5.128575086593628
# Tortuga AP: 0.7331176030735598
# Pez AP: 0.46487838426140926
# mAP = 0.5989979936674845
# 144/234
# Elapsed time = 5.441373109817505
# Tortuga AP: 0.7365262427195743
# Pez AP: 0.4647163451302049
# mAP = 0.6006212939248896
# 145/234
# Elapsed time = 5.180502414703369
# Tortuga AP: 0.7372865817754772
# Pez AP: 0.46455729181553373
# mAP = 0.6009219367955054
# 146/234
# Elapsed time = 6.153426170349121
# Tortuga AP: 0.7374838504523754
# Pez AP: 0.46455729181553373
# mAP = 0.6010205711339546
# 147/234
# Elapsed time = 4.952983856201172
# Tortuga AP: 0.7399701483089755
# Pez AP: 0.46455729181553373
# mAP = 0.6022637200622546
# 148/234
# Elapsed time = 5.019582271575928
# Tortuga AP: 0.7378625651071219
# Pez AP: 0.4627511202547403
# mAP = 0.600306842680931
# 149/234
# Elapsed time = 5.025615215301514
# Tortuga AP: 0.739667471023677
# Pez AP: 0.46145810982614965
# mAP = 0.6005627904249133
# 150/234
# Elapsed time = 4.7986085414886475
# Tortuga AP: 0.7436292029679189
# Pez AP: 0.46145810982614965
# mAP = 0.6025436563970343
# 151/234
# Elapsed time = 4.897388458251953
# Tortuga AP: 0.7434428075659317
# Pez AP: 0.46145810982614965
# mAP = 0.6024504586960406
# 152/234
# Elapsed time = 5.126725912094116
# Tortuga AP: 0.7448465807100175
# Pez AP: 0.46145810982614965
# mAP = 0.6031523452680836
# 153/234
# Elapsed time = 4.987740516662598
# Tortuga AP: 0.7475873646985197
# Pez AP: 0.46145810982614965
# mAP = 0.6045227372623347
# 154/234
# Elapsed time = 5.246881484985352
# Tortuga AP: 0.7493188497690152
# Pez AP: 0.46022586440593055
# mAP = 0.6047723570874729
# 155/234
# Elapsed time = 6.002928256988525
# Tortuga AP: 0.7497960828029282
# Pez AP: 0.45410503854605844
# mAP = 0.6019505606744933
# 156/234
# Elapsed time = 4.903172016143799
# Tortuga AP: 0.7522470006635202
# Pez AP: 0.45364965116866474
# mAP = 0.6029483259160925
# 157/234
# Elapsed time = 4.859604120254517
# Tortuga AP: 0.7540333521409295
# Pez AP: 0.45320960058682597
# mAP = 0.6036214763638778
# 158/234
# Elapsed time = 5.655209541320801
# Tortuga AP: 0.7552034199092744
# Pez AP: 0.45320960058682597
# mAP = 0.6042065102480502
# 159/234
# Elapsed time = 4.893823862075806
# Tortuga AP: 0.7575888497111279
# Pez AP: 0.4530703570209296
# mAP = 0.6053296033660288
# 160/234
# Elapsed time = 5.533815383911133
# Tortuga AP: 0.7559288012944227
# Pez AP: 0.45292270693558045
# mAP = 0.6044257541150015
# 161/234
# Elapsed time = 5.402005910873413
# Tortuga AP: 0.7574716934437631
# Pez AP: 0.4527830398451812
# mAP = 0.6051273666444721
# 162/234
# Elapsed time = 4.945905685424805
# Tortuga AP: 0.7576006874395375
# Pez AP: 0.4527830398451812
# mAP = 0.6051918636423593
# 163/234
# Elapsed time = 5.987276315689087
# Tortuga AP: 0.7585798655818056
# Pez AP: 0.4527830398451812
# mAP = 0.6056814527134934
# 164/234
# Elapsed time = 5.098324537277222
# Tortuga AP: 0.7578412040604182
# Pez AP: 0.4527830398451812
# mAP = 0.6053121219527997
# 165/234
# Elapsed time = 5.180909872055054
# Tortuga AP: 0.7512916205140965
# Pez AP: 0.4527830398451812
# mAP = 0.6020373301796389
# 166/234
# Elapsed time = 5.2129693031311035
# Tortuga AP: 0.752475556684738
# Pez AP: 0.4527830398451812
# mAP = 0.6026292982649596
# 167/234
# Elapsed time = 5.060504913330078
# Tortuga AP: 0.7538668460152151
# Pez AP: 0.4527830398451812
# mAP = 0.6033249429301981
# 168/234
# Elapsed time = 5.328038215637207
# Tortuga AP: 0.7535806943489888
# Pez AP: 0.4527830398451812
# mAP = 0.603181867097085
# 169/234
# Elapsed time = 5.362965106964111
# Tortuga AP: 0.7543509423164246
# Pez AP: 0.4527830398451812
# mAP = 0.6035669910808029
# 170/234
# Elapsed time = 5.335732460021973
# Tortuga AP: 0.7549402573176138
# Pez AP: 0.4526447489123697
# mAP = 0.6037925031149918
# 171/234
# Elapsed time = 5.13064980506897
# Tortuga AP: 0.7572853881365815
# Pez AP: 0.4525019490478242
# mAP = 0.6048936685922028
# 172/234
# Elapsed time = 5.025291442871094
# Tortuga AP: 0.7580924809750528
# Pez AP: 0.4525019490478242
# mAP = 0.6052972150114385
# 173/234
# Elapsed time = 5.804168939590454
# Tortuga AP: 0.7589694917145097
# Pez AP: 0.45236428778284704
# mAP = 0.6056668897486783
# 174/234
# Elapsed time = 5.4956910610198975
# Tortuga AP: 0.7604278310392613
# Pez AP: 0.45236428778284704
# mAP = 0.6063960594110541
# 175/234
# Elapsed time = 5.072957754135132
# Tortuga AP: 0.7624313928720426
# Pez AP: 0.4520624670326754
# mAP = 0.6072469299523591
# 176/234
# Elapsed time = 5.066884279251099
# Tortuga AP: 0.7624313928720426
# Pez AP: 0.4483752008516646
# mAP = 0.6054032968618537
# 177/234
# Elapsed time = 5.179367780685425
# Tortuga AP: 0.7624313928720426
# Pez AP: 0.4481986574480908
# mAP = 0.6053150251600667
# 178/234
# Elapsed time = 5.117392063140869
# Tortuga AP: 0.7624313928720426
# Pez AP: 0.45775181263126974
# mAP = 0.6100916027516562
# 179/234
# Elapsed time = 5.237555742263794
# Tortuga AP: 0.7624313928720426
# Pez AP: 0.4440650707315862
# mAP = 0.6032482318018144
# 180/234
# Elapsed time = 5.284863710403442
# Tortuga AP: 0.7624313928720426
# Pez AP: 0.44621827660921404
# mAP = 0.6043248347406284
# 181/234
# Elapsed time = 5.406577825546265
# Tortuga AP: 0.7624313928720426
# Pez AP: 0.4425510035240594
# mAP = 0.602491198198051
# 182/234
# Elapsed time = 5.203505039215088
# Tortuga AP: 0.7624313928720426
# Pez AP: 0.4411425252782335
# mAP = 0.6017869590751381
# 183/234
# Elapsed time = 5.812610626220703
# Tortuga AP: 0.7624313928720426
# Pez AP: 0.4430252455728139
# mAP = 0.6027283192224283
# 184/234
# Elapsed time = 5.25081992149353
# Tortuga AP: 0.7624313928720426
# Pez AP: 0.44568098369029907
# mAP = 0.6040561882811708
# 185/234
# Elapsed time = 5.194525718688965
# Tortuga AP: 0.7624313928720426
# Pez AP: 0.4475544868225749
# mAP = 0.6049929398473088
# 186/234
# Elapsed time = 5.314249038696289
# Tortuga AP: 0.7624313928720426
# Pez AP: 0.45105996927372394
# mAP = 0.6067456810728833
# 187/234
# Elapsed time = 5.361430644989014
# Tortuga AP: 0.7624313928720426
# Pez AP: 0.45367898305538223
# mAP = 0.6080551879637124
# 188/234
# Elapsed time = 6.450220823287964
# Tortuga AP: 0.7624313928720426
# Pez AP: 0.4571635008774951
# mAP = 0.6097974468747689
# 189/234
# Elapsed time = 5.225744724273682
# Tortuga AP: 0.7624313928720426
# Pez AP: 0.4601294611188712
# mAP = 0.6112804269954569
# 190/234
# Elapsed time = 5.440764665603638
# Tortuga AP: 0.76207378991543
# Pez AP: 0.46085418554312463
# mAP = 0.6114639877292773
# 191/234
# Elapsed time = 5.434854984283447
# Tortuga AP: 0.76207378991543
# Pez AP: 0.4637207812580333
# mAP = 0.6128972855867316
# 192/234
# Elapsed time = 5.740669012069702
# Tortuga AP: 0.76207378991543
# Pez AP: 0.46716369507165406
# mAP = 0.614618742493542
# 193/234
# Elapsed time = 5.08112096786499
# Tortuga AP: 0.76207378991543
# Pez AP: 0.4647498714118954
# mAP = 0.6134118306636627
# 194/234
# Elapsed time = 5.145781517028809
# Tortuga AP: 0.76207378991543
# Pez AP: 0.46579641830656204
# mAP = 0.6139351041109959
# 195/234
# Elapsed time = 5.212823390960693
# Tortuga AP: 0.761689877108074
# Pez AP: 0.46811935214551004
# mAP = 0.614904614626792
# 196/234
# Elapsed time = 5.789425373077393
# Tortuga AP: 0.7615795646335258
# Pez AP: 0.4733571301622911
# mAP = 0.6174683473979085
# 197/234
# Elapsed time = 5.115131855010986
# Tortuga AP: 0.7615104866923856
# Pez AP: 0.4707644320569965
# mAP = 0.6161374593746911
# 198/234
# Elapsed time = 5.221369743347168
# Tortuga AP: 0.7614329532427809
# Pez AP: 0.4707947469918685
# mAP = 0.6161138501173247
# 199/234
# Elapsed time = 5.260295867919922
# Tortuga AP: 0.7614329532427809
# Pez AP: 0.4604432120954368
# mAP = 0.6109380826691089
# 200/234
# Elapsed time = 5.203904151916504
# Tortuga AP: 0.7614329532427809
# Pez AP: 0.45988734457826785
# mAP = 0.6106601489105243
# 201/234
# Elapsed time = 5.1306235790252686
# Tortuga AP: 0.7614329532427809
# Pez AP: 0.4570468773101304
# mAP = 0.6092399152764556
# 202/234
# Elapsed time = 5.532174110412598
# Tortuga AP: 0.7613642950772874
# Pez AP: 0.4518103947108617
# mAP = 0.6065873448940746
# 203/234
# Elapsed time = 5.434242248535156
# Tortuga AP: 0.7613642950772874
# Pez AP: 0.45220549124417225
# mAP = 0.6067848931607298
# 204/234
# Elapsed time = 5.130380868911743
# Tortuga AP: 0.7613642950772874
# Pez AP: 0.45506234881215013
# mAP = 0.6082133219447188
# 205/234
# Elapsed time = 5.057085275650024
# Tortuga AP: 0.7612550580474092
# Pez AP: 0.45580156412801853
# mAP = 0.6085283110877139
# 206/234
# Elapsed time = 5.629615306854248
# Tortuga AP: 0.7612550580474092
# Pez AP: 0.45862603614927566
# mAP = 0.6099405470983424
# 207/234
# Elapsed time = 5.662207126617432
# Tortuga AP: 0.7609550184410863
# Pez AP: 0.45397851160392205
# mAP = 0.6074667650225042
# 208/234
# Elapsed time = 5.078823566436768
# Tortuga AP: 0.7609550184410863
# Pez AP: 0.45412831668568043
# mAP = 0.6075416675633833
# 209/234
# Elapsed time = 5.185672044754028
# Tortuga AP: 0.7608875968935976
# Pez AP: 0.4544953449371427
# mAP = 0.6076914709153702
# 210/234
# Elapsed time = 5.153512716293335
# Tortuga AP: 0.7608875968935976
# Pez AP: 0.45582607412797244
# mAP = 0.608356835510785
# 211/234
# Elapsed time = 5.2077906131744385
# Tortuga AP: 0.7608875968935976
# Pez AP: 0.45553107924207575
# mAP = 0.6082093380678367
# 212/234
# Elapsed time = 5.084576368331909
# Tortuga AP: 0.7608875968935976
# Pez AP: 0.45557038974814945
# mAP = 0.6082289933208735
# 213/234
# Elapsed time = 4.989338636398315
# Tortuga AP: 0.7608245653463082
# Pez AP: 0.4434185832908488
# mAP = 0.6021215743185785
# 214/234
# Elapsed time = 4.987851858139038
# Tortuga AP: 0.7608245653463082
# Pez AP: 0.44390675801036716
# mAP = 0.6023656616783377
# 215/234
# Elapsed time = 5.18610692024231
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.44348638002155244
# mAP = 0.6020018546211053
# 216/234
# Elapsed time = 5.046625137329102
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.4430108512816576
# mAP = 0.601764090251158
# 217/234
# Elapsed time = 4.908149242401123
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.4435926182884783
# mAP = 0.6020549737545683
# 218/234
# Elapsed time = 5.0907957553863525
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.429448341992943
# mAP = 0.5949828356068007
# 219/234
# Elapsed time = 5.003473997116089
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.4294941591294037
# mAP = 0.5950057441750309
# 220/234
# Elapsed time = 5.026573896408081
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.42738658595057305
# mAP = 0.5939519575856157
# 221/234
# Elapsed time = 5.334249973297119
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.4287839912213419
# mAP = 0.5946506602210001
# 222/234
# Elapsed time = 5.195856809616089
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.4300504618815627
# mAP = 0.5952838955511105
# 223/234
# Elapsed time = 5.167423248291016
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.42942756274696914
# mAP = 0.5949724459838137
# 224/234
# Elapsed time = 5.094926118850708
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.431979303235672
# mAP = 0.5962483162281651
# 225/234
# Elapsed time = 5.080676794052124
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.42914018171408747
# mAP = 0.5948287554673729
# 226/234
# Elapsed time = 5.645084857940674
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.43066376603510004
# mAP = 0.5955905476278791
# 227/234
# Elapsed time = 5.159020185470581
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.43170430999871257
# mAP = 0.5961108196096854
# 228/234
# Elapsed time = 4.9661900997161865
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.4325435032707744
# mAP = 0.5965304162457163
# 229/234
# Elapsed time = 5.4931745529174805
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.4342865524452712
# mAP = 0.5974019408329647
# 230/234
# Elapsed time = 5.588268518447876
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.43357077473924155
# mAP = 0.5970440519799499
# 231/234
# Elapsed time = 5.352448225021362
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.4351654468807664
# mAP = 0.5978413880507123
# 232/234
# Elapsed time = 5.2418553829193115
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.4294343502619316
# mAP = 0.594975839741295
# 233/234
# Elapsed time = 5.105125188827515
# Tortuga AP: 0.7605173292206583
# Pez AP: 0.43049615012983566
# mAP = 0.5955067396752469
#
# mean average precision: nan

# %%
mAP = [mAP for mAP in mAPs if str(mAP)!='nan']
mean_average_prec = round(np.mean(np.array(mAP)), 3)
print('After training %dk batches, the mean average precision is %0.3f'%(len(record_df), mean_average_prec))

# record_df.loc[len(record_df)-1, 'mAP'] = mean_average_prec
# record_df.to_csv(C.record_path, index=0)
# print('Save mAP to {}'.format(C.record_path))
# Out:
# After training 100k batches, the mean average precision is 0.594

# %% [markdown]
# # PROCESAMIENTO DE VIDEO

# %%
#PROCESAMIENTO DEL VIDEO
# caprturar el video y procesarlo frame a frame, esto  procesa cada imagen y las guarda en un archivo en drive dispuesto por usted.
cap = cv2.VideoCapture('acuario.mp4') #Cargue aqui el video
frame_count = 0
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 960) #Usted puede decidir cambiar el alto
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 540) #Tambien el ancho
 
while True:
  ret, img = cap.read()


  X, ratio = format_img(img, C)
    
    # Change X (img) shape from (1, channel, height, width) to (1, height, width, channel)
  X = np.transpose(X, (0, 2, 3, 1))

  if not ret:
    break
  frame_count += 1
  print('Numero de frames : {0}'.format(frame_count))
  results = model_rpn.predict(X) #Esta linea debe ser interpretada y arreglada por ustedes dado que es el modelo qu ustedes entrenaron y va a detectar.
 
# get the feature maps and output from the RPN
  [Y1, Y2, F] = model_rpn.predict(X)


    # Get bboxes by applying NMS 
  # R.shape = (300, 4)
  #R = rpn_to_roi(Y1, Y2, C, K.image_dim_ordering(), overlap_thresh=0.7)
  R = rpn_to_roi(Y1, Y2, C, K.image_data_format(), overlap_thresh=0.7)

  # convert from (x1,y1,x2,y2) to (x,y,w,h)
  R[:, 2] -= R[:, 0]
  R[:, 3] -= R[:, 1]

  # apply the spatial pyramid pooling to the proposed regions
  bboxes = {}
  probs = {}

  for jk in range(R.shape[0]//C.num_rois + 1):
      ROIs = np.expand_dims(R[C.num_rois*jk:C.num_rois*(jk+1), :], axis=0)
      if ROIs.shape[1] == 0:
          break

      if jk == R.shape[0]//C.num_rois:
          #pad R
          curr_shape = ROIs.shape
          target_shape = (curr_shape[0],C.num_rois,curr_shape[2])
          ROIs_padded = np.zeros(target_shape).astype(ROIs.dtype)
          ROIs_padded[:, :curr_shape[1], :] = ROIs
          ROIs_padded[0, curr_shape[1]:, :] = ROIs[0, 0, :]
          ROIs = ROIs_padded

      [P_cls, P_regr] = model_classifier_only.predict([F, ROIs])

      # Calculate bboxes coordinates on resized image
      for ii in range(P_cls.shape[1]):
          # Ignore 'bg' class
          if np.max(P_cls[0, ii, :]) < bbox_threshold or np.argmax(P_cls[0, ii, :]) == (P_cls.shape[2] - 1):
              continue

          cls_name = class_mapping[np.argmax(P_cls[0, ii, :])]

          if cls_name not in bboxes:
              bboxes[cls_name] = []
              probs[cls_name] = []

          (x, y, w, h) = ROIs[0, ii, :]

          cls_num = np.argmax(P_cls[0, ii, :])
          try:
              (tx, ty, tw, th) = P_regr[0, ii, 4*cls_num:4*(cls_num+1)]
              tx /= C.classifier_regr_std[0]
              ty /= C.classifier_regr_std[1]
              tw /= C.classifier_regr_std[2]
              th /= C.classifier_regr_std[3]
              x, y, w, h = apply_regr(x, y, w, h, tx, ty, tw, th)
          except:
              pass
          bboxes[cls_name].append([C.rpn_stride*x, C.rpn_stride*y, C.rpn_stride*(x+w), C.rpn_stride*(y+h)])
          probs[cls_name].append(np.max(P_cls[0, ii, :]))

  all_dets = []

  for key in bboxes:
      bbox = np.array(bboxes[key])

      new_boxes, new_probs = non_max_suppression_fast(bbox, np.array(probs[key]), overlap_thresh=0.2)
      for jk in range(new_boxes.shape[0]):
          (x1, y1, x2, y2) = new_boxes[jk,:]

          # Calculate real coordinates on original image
          (real_x1, real_y1, real_x2, real_y2) = get_real_coordinates(ratio, x1, y1, x2, y2)

          cv2.rectangle(img,(real_x1, real_y1), (real_x2, real_y2), (int(class_to_color[key][0]), int(class_to_color[key][1]), int(class_to_color[key][2])),4)

          textLabel = '{}: {}'.format(key,int(100*new_probs[jk]))
          all_dets.append((key,100*new_probs[jk]))

          (retval,baseLine) = cv2.getTextSize(textLabel,cv2.FONT_HERSHEY_COMPLEX,1,1)
          textOrg = (real_x1, real_y1-0)

          cv2.rectangle(img, (textOrg[0] - 5, textOrg[1]+baseLine - 5), (textOrg[0]+retval[0] + 5, textOrg[1]-retval[1] - 5), (0, 0, 0), 1)
          cv2.rectangle(img, (textOrg[0] - 5,textOrg[1]+baseLine - 5), (textOrg[0]+retval[0] + 5, textOrg[1]-retval[1] - 5), (255, 255, 255), -1)
          cv2.putText(img, textLabel, textOrg, cv2.FONT_HERSHEY_DUPLEX, 1, (0, 0, 0), 1)
  
 
  fname= '{0}.jpg'.format(frame_count)
  fname = os.path.join('/content/drive/MyDrive/FasterRCNN/video2',fname) #Crea la ruta donde ira cada imagen procesada.
  cv2.imwrite(fname, img) #Escribe cada imagen a disco
  print('El archivo fue escrito en :{0}',format(fname))
cap.release()

#Nota: Los nombres de las imagenes procesadas seran numeros ordenados, de tal manera que puedan ser procesados facilmente a continuacion y crear un video a partir de los frames.
# Out:
# Numero de frames : 1
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/1.jpg
# Numero de frames : 2
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/2.jpg
# Numero de frames : 3
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/3.jpg
# Numero de frames : 4
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/4.jpg
# Numero de frames : 5
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/5.jpg
# Numero de frames : 6
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/6.jpg
# Numero de frames : 7
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/7.jpg
# Numero de frames : 8
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/8.jpg
# Numero de frames : 9
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/9.jpg
# Numero de frames : 10
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/10.jpg
# Numero de frames : 11
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/11.jpg
# Numero de frames : 12
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/12.jpg
# Numero de frames : 13
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/13.jpg
# Numero de frames : 14
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/14.jpg
# Numero de frames : 15
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/15.jpg
# Numero de frames : 16
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/16.jpg
# Numero de frames : 17
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/17.jpg
# Numero de frames : 18
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/18.jpg
# Numero de frames : 19
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/19.jpg
# Numero de frames : 20
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/20.jpg
# Numero de frames : 21
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/21.jpg
# Numero de frames : 22
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/22.jpg
# Numero de frames : 23
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/23.jpg
# Numero de frames : 24
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/24.jpg
# Numero de frames : 25
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/25.jpg
# Numero de frames : 26
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/26.jpg
# Numero de frames : 27
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/27.jpg
# Numero de frames : 28
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/28.jpg
# Numero de frames : 29
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/29.jpg
# Numero de frames : 30
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/30.jpg
# Numero de frames : 31
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/31.jpg
# Numero de frames : 32
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/32.jpg
# Numero de frames : 33
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/33.jpg
# Numero de frames : 34
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/34.jpg
# Numero de frames : 35
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/35.jpg
# Numero de frames : 36
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/36.jpg
# Numero de frames : 37
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/37.jpg
# Numero de frames : 38
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/38.jpg
# Numero de frames : 39
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/39.jpg
# Numero de frames : 40
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/40.jpg
# Numero de frames : 41
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/41.jpg
# Numero de frames : 42
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/42.jpg
# Numero de frames : 43
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/43.jpg
# Numero de frames : 44
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/44.jpg
# Numero de frames : 45
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/45.jpg
# Numero de frames : 46
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/46.jpg
# Numero de frames : 47
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/47.jpg
# Numero de frames : 48
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/48.jpg
# Numero de frames : 49
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/49.jpg
# Numero de frames : 50
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/50.jpg
# Numero de frames : 51
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/51.jpg
# Numero de frames : 52
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/52.jpg
# Numero de frames : 53
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/53.jpg
# Numero de frames : 54
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/54.jpg
# Numero de frames : 55
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/55.jpg
# Numero de frames : 56
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/56.jpg
# Numero de frames : 57
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/57.jpg
# Numero de frames : 58
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/58.jpg
# Numero de frames : 59
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/59.jpg
# Numero de frames : 60
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/60.jpg
# Numero de frames : 61
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/61.jpg
# Numero de frames : 62
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/62.jpg
# Numero de frames : 63
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/63.jpg
# Numero de frames : 64
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/64.jpg
# Numero de frames : 65
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/65.jpg
# Numero de frames : 66
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/66.jpg
# Numero de frames : 67
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/67.jpg
# Numero de frames : 68
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/68.jpg
# Numero de frames : 69
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/69.jpg
# Numero de frames : 70
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/70.jpg
# Numero de frames : 71
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/71.jpg
# Numero de frames : 72
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/72.jpg
# Numero de frames : 73
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/73.jpg
# Numero de frames : 74
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/74.jpg
# Numero de frames : 75
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/75.jpg
# Numero de frames : 76
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/76.jpg
# Numero de frames : 77
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/77.jpg
# Numero de frames : 78
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/78.jpg
# Numero de frames : 79
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/79.jpg
# Numero de frames : 80
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/80.jpg
# Numero de frames : 81
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/81.jpg
# Numero de frames : 82
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/82.jpg
# Numero de frames : 83
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/83.jpg
# Numero de frames : 84
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/84.jpg
# Numero de frames : 85
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/85.jpg
# Numero de frames : 86
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/86.jpg
# Numero de frames : 87
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/87.jpg
# Numero de frames : 88
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/88.jpg
# Numero de frames : 89
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/89.jpg
# Numero de frames : 90
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/90.jpg
# Numero de frames : 91
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/91.jpg
# Numero de frames : 92
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/92.jpg
# Numero de frames : 93
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/93.jpg
# Numero de frames : 94
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/94.jpg
# Numero de frames : 95
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/95.jpg
# Numero de frames : 96
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/96.jpg
# Numero de frames : 97
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/97.jpg
# Numero de frames : 98
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/98.jpg
# Numero de frames : 99
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/99.jpg
# Numero de frames : 100
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/100.jpg
# Numero de frames : 101
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/101.jpg
# Numero de frames : 102
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/102.jpg
# Numero de frames : 103
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/103.jpg
# Numero de frames : 104
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/104.jpg
# Numero de frames : 105
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/105.jpg
# Numero de frames : 106
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/106.jpg
# Numero de frames : 107
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/107.jpg
# Numero de frames : 108
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/108.jpg
# Numero de frames : 109
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/109.jpg
# Numero de frames : 110
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/110.jpg
# Numero de frames : 111
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/111.jpg
# Numero de frames : 112
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/112.jpg
# Numero de frames : 113
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/113.jpg
# Numero de frames : 114
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/114.jpg
# Numero de frames : 115
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/115.jpg
# Numero de frames : 116
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/116.jpg
# Numero de frames : 117
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/117.jpg
# Numero de frames : 118
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/118.jpg
# Numero de frames : 119
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/119.jpg
# Numero de frames : 120
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/120.jpg
# Numero de frames : 121
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/121.jpg
# Numero de frames : 122
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/122.jpg
# Numero de frames : 123
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/123.jpg
# Numero de frames : 124
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/124.jpg
# Numero de frames : 125
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/125.jpg
# Numero de frames : 126
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/126.jpg
# Numero de frames : 127
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/127.jpg
# Numero de frames : 128
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/128.jpg
# Numero de frames : 129
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/129.jpg
# Numero de frames : 130
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/130.jpg
# Numero de frames : 131
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/131.jpg
# Numero de frames : 132
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/132.jpg
# Numero de frames : 133
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/133.jpg
# Numero de frames : 134
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/134.jpg
# Numero de frames : 135
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/135.jpg
# Numero de frames : 136
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/136.jpg
# Numero de frames : 137
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/137.jpg
# Numero de frames : 138
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/138.jpg
# Numero de frames : 139
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/139.jpg
# Numero de frames : 140
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/140.jpg
# Numero de frames : 141
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/141.jpg
# Numero de frames : 142
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/142.jpg
# Numero de frames : 143
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/143.jpg
# Numero de frames : 144
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/144.jpg
# Numero de frames : 145
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/145.jpg
# Numero de frames : 146
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/146.jpg
# Numero de frames : 147
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/147.jpg
# Numero de frames : 148
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/148.jpg
# Numero de frames : 149
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/149.jpg
# Numero de frames : 150
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/150.jpg
# Numero de frames : 151
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/151.jpg
# Numero de frames : 152
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/152.jpg
# Numero de frames : 153
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/153.jpg
# Numero de frames : 154
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/154.jpg
# Numero de frames : 155
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/155.jpg
# Numero de frames : 156
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/156.jpg
# Numero de frames : 157
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/157.jpg
# Numero de frames : 158
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/158.jpg
# Numero de frames : 159
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/159.jpg
# Numero de frames : 160
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/160.jpg
# Numero de frames : 161
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/161.jpg
# Numero de frames : 162
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/162.jpg
# Numero de frames : 163
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/163.jpg
# Numero de frames : 164
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/164.jpg
# Numero de frames : 165
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/165.jpg
# Numero de frames : 166
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/166.jpg
# Numero de frames : 167
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/167.jpg
# Numero de frames : 168
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/168.jpg
# Numero de frames : 169
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/169.jpg
# Numero de frames : 170
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/170.jpg
# Numero de frames : 171
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/171.jpg
# Numero de frames : 172
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/172.jpg
# Numero de frames : 173
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/173.jpg
# Numero de frames : 174
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/174.jpg
# Numero de frames : 175
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/175.jpg
# Numero de frames : 176
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/176.jpg
# Numero de frames : 177
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/177.jpg
# Numero de frames : 178
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/178.jpg
# Numero de frames : 179
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/179.jpg
# Numero de frames : 180
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/180.jpg
# Numero de frames : 181
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/181.jpg
# Numero de frames : 182
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/182.jpg
# Numero de frames : 183
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/183.jpg
# Numero de frames : 184
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/184.jpg
# Numero de frames : 185
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/185.jpg
# Numero de frames : 186
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/186.jpg
# Numero de frames : 187
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/187.jpg
# Numero de frames : 188
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/188.jpg
# Numero de frames : 189
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/189.jpg
# Numero de frames : 190
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/190.jpg
# Numero de frames : 191
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/191.jpg
# Numero de frames : 192
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/192.jpg
# Numero de frames : 193
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/193.jpg
# Numero de frames : 194
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/194.jpg
# Numero de frames : 195
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/195.jpg
# Numero de frames : 196
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/196.jpg
# Numero de frames : 197
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/197.jpg
# Numero de frames : 198
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/198.jpg
# Numero de frames : 199
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/199.jpg
# Numero de frames : 200
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/200.jpg
# Numero de frames : 201
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/201.jpg
# Numero de frames : 202
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/202.jpg
# Numero de frames : 203
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/203.jpg
# Numero de frames : 204
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/204.jpg
# Numero de frames : 205
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/205.jpg
# Numero de frames : 206
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/206.jpg
# Numero de frames : 207
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/207.jpg
# Numero de frames : 208
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/208.jpg
# Numero de frames : 209
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/209.jpg
# Numero de frames : 210
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/210.jpg
# Numero de frames : 211
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/211.jpg
# Numero de frames : 212
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/212.jpg
# Numero de frames : 213
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/213.jpg
# Numero de frames : 214
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/214.jpg
# Numero de frames : 215
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/215.jpg
# Numero de frames : 216
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/216.jpg
# Numero de frames : 217
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/217.jpg
# Numero de frames : 218
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/218.jpg
# Numero de frames : 219
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/219.jpg
# Numero de frames : 220
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/220.jpg
# Numero de frames : 221
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/221.jpg
# Numero de frames : 222
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/222.jpg
# Numero de frames : 223
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/223.jpg
# Numero de frames : 224
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/224.jpg
# Numero de frames : 225
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/225.jpg
# Numero de frames : 226
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/226.jpg
# Numero de frames : 227
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/227.jpg
# Numero de frames : 228
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/228.jpg
# Numero de frames : 229
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/229.jpg
# Numero de frames : 230
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/230.jpg
# Numero de frames : 231
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/231.jpg
# Numero de frames : 232
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/232.jpg
# Numero de frames : 233
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/233.jpg
# Numero de frames : 234
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/234.jpg
# Numero de frames : 235
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/235.jpg
# Numero de frames : 236
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/236.jpg
# Numero de frames : 237
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/237.jpg
# Numero de frames : 238
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/238.jpg
# Numero de frames : 239
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/239.jpg
# Numero de frames : 240
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/240.jpg
# Numero de frames : 241
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/241.jpg
# Numero de frames : 242
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/242.jpg
# Numero de frames : 243
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/243.jpg
# Numero de frames : 244
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/244.jpg
# Numero de frames : 245
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/245.jpg
# Numero de frames : 246
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/246.jpg
# Numero de frames : 247
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/247.jpg
# Numero de frames : 248
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/248.jpg
# Numero de frames : 249
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/249.jpg
# Numero de frames : 250
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/250.jpg
# Numero de frames : 251
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/251.jpg
# Numero de frames : 252
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/252.jpg
# Numero de frames : 253
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/253.jpg
# Numero de frames : 254
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/254.jpg
# Numero de frames : 255
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/255.jpg
# Numero de frames : 256
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/256.jpg
# Numero de frames : 257
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/257.jpg
# Numero de frames : 258
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/258.jpg
# Numero de frames : 259
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/259.jpg
# Numero de frames : 260
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/260.jpg
# Numero de frames : 261
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/261.jpg
# Numero de frames : 262
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/262.jpg
# Numero de frames : 263
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/263.jpg
# Numero de frames : 264
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/264.jpg
# Numero de frames : 265
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/265.jpg
# Numero de frames : 266
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/266.jpg
# Numero de frames : 267
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/267.jpg
# Numero de frames : 268
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/268.jpg
# Numero de frames : 269
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/269.jpg
# Numero de frames : 270
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/270.jpg
# Numero de frames : 271
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/271.jpg
# Numero de frames : 272
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/272.jpg
# Numero de frames : 273
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/273.jpg
# Numero de frames : 274
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/274.jpg
# Numero de frames : 275
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/275.jpg
# Numero de frames : 276
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/276.jpg
# Numero de frames : 277
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/277.jpg
# Numero de frames : 278
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/278.jpg
# Numero de frames : 279
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/279.jpg
# Numero de frames : 280
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/280.jpg
# Numero de frames : 281
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/281.jpg
# Numero de frames : 282
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/282.jpg
# Numero de frames : 283
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/283.jpg
# Numero de frames : 284
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/284.jpg
# Numero de frames : 285
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/285.jpg
# Numero de frames : 286
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/286.jpg
# Numero de frames : 287
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/287.jpg
# Numero de frames : 288
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/288.jpg
# Numero de frames : 289
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/289.jpg
# Numero de frames : 290
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/290.jpg
# Numero de frames : 291
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/291.jpg
# Numero de frames : 292
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/292.jpg
# Numero de frames : 293
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/293.jpg
# Numero de frames : 294
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/294.jpg
# Numero de frames : 295
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/295.jpg
# Numero de frames : 296
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/296.jpg
# Numero de frames : 297
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/297.jpg
# Numero de frames : 298
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/298.jpg
# Numero de frames : 299
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/299.jpg
# Numero de frames : 300
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/300.jpg
# Numero de frames : 301
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/301.jpg
# Numero de frames : 302
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/302.jpg
# Numero de frames : 303
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/303.jpg
# Numero de frames : 304
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/304.jpg
# Numero de frames : 305
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/305.jpg
# Numero de frames : 306
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/306.jpg
# Numero de frames : 307
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/307.jpg
# Numero de frames : 308
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/308.jpg
# Numero de frames : 309
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/309.jpg
# Numero de frames : 310
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/310.jpg
# Numero de frames : 311
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/311.jpg
# Numero de frames : 312
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/312.jpg
# Numero de frames : 313
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/313.jpg
# Numero de frames : 314
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/314.jpg
# Numero de frames : 315
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/315.jpg
# Numero de frames : 316
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/316.jpg
# Numero de frames : 317
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/317.jpg
# Numero de frames : 318
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/318.jpg
# Numero de frames : 319
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/319.jpg
# Numero de frames : 320
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/320.jpg
# Numero de frames : 321
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/321.jpg
# Numero de frames : 322
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/322.jpg
# Numero de frames : 323
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/323.jpg
# Numero de frames : 324
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/324.jpg
# Numero de frames : 325
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/325.jpg
# Numero de frames : 326
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/326.jpg
# Numero de frames : 327
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/327.jpg
# Numero de frames : 328
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/328.jpg
# Numero de frames : 329
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/329.jpg
# Numero de frames : 330
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/330.jpg
# Numero de frames : 331
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/331.jpg
# Numero de frames : 332
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/332.jpg
# Numero de frames : 333
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/333.jpg
# Numero de frames : 334
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/334.jpg
# Numero de frames : 335
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/335.jpg
# Numero de frames : 336
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/336.jpg
# Numero de frames : 337
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/337.jpg
# Numero de frames : 338
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/338.jpg
# Numero de frames : 339
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/339.jpg
# Numero de frames : 340
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/340.jpg
# Numero de frames : 341
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/341.jpg
# Numero de frames : 342
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/342.jpg
# Numero de frames : 343
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/343.jpg
# Numero de frames : 344
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/344.jpg
# Numero de frames : 345
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/345.jpg
# Numero de frames : 346
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/346.jpg
# Numero de frames : 347
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/347.jpg
# Numero de frames : 348
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/348.jpg
# Numero de frames : 349
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/349.jpg
# Numero de frames : 350
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/350.jpg
# Numero de frames : 351
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/351.jpg
# Numero de frames : 352
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/352.jpg
# Numero de frames : 353
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/353.jpg
# Numero de frames : 354
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/354.jpg
# Numero de frames : 355
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/355.jpg
# Numero de frames : 356
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/356.jpg
# Numero de frames : 357
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/357.jpg
# Numero de frames : 358
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/358.jpg
# Numero de frames : 359
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/359.jpg
# Numero de frames : 360
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/360.jpg
# Numero de frames : 361
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/361.jpg
# Numero de frames : 362
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/362.jpg
# Numero de frames : 363
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/363.jpg
# Numero de frames : 364
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/364.jpg
# Numero de frames : 365
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/365.jpg
# Numero de frames : 366
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/366.jpg
# Numero de frames : 367
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/367.jpg
# Numero de frames : 368
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/368.jpg
# Numero de frames : 369
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/369.jpg
# Numero de frames : 370
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/370.jpg
# Numero de frames : 371
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/371.jpg
# Numero de frames : 372
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/372.jpg
# Numero de frames : 373
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/373.jpg
# Numero de frames : 374
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/374.jpg
# Numero de frames : 375
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/375.jpg
# Numero de frames : 376
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/376.jpg
# Numero de frames : 377
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/377.jpg
# Numero de frames : 378
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/378.jpg
# Numero de frames : 379
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/379.jpg
# Numero de frames : 380
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/380.jpg
# Numero de frames : 381
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/381.jpg
# Numero de frames : 382
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/382.jpg
# Numero de frames : 383
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/383.jpg
# Numero de frames : 384
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/384.jpg
# Numero de frames : 385
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/385.jpg
# Numero de frames : 386
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/386.jpg
# Numero de frames : 387
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/387.jpg
# Numero de frames : 388
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/388.jpg
# Numero de frames : 389
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/389.jpg
# Numero de frames : 390
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/390.jpg
# Numero de frames : 391
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/391.jpg
# Numero de frames : 392
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/392.jpg
# Numero de frames : 393
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/393.jpg
# Numero de frames : 394
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/394.jpg
# Numero de frames : 395
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/395.jpg
# Numero de frames : 396
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/396.jpg
# Numero de frames : 397
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/397.jpg
# Numero de frames : 398
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/398.jpg
# Numero de frames : 399
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/399.jpg
# Numero de frames : 400
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/400.jpg
# Numero de frames : 401
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/401.jpg
# Numero de frames : 402
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/402.jpg
# Numero de frames : 403
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/403.jpg
# Numero de frames : 404
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/404.jpg
# Numero de frames : 405
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/405.jpg
# Numero de frames : 406
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/406.jpg
# Numero de frames : 407
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/407.jpg
# Numero de frames : 408
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/408.jpg
# Numero de frames : 409
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/409.jpg
# Numero de frames : 410
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/410.jpg
# Numero de frames : 411
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/411.jpg
# Numero de frames : 412
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/412.jpg
# Numero de frames : 413
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/413.jpg
# Numero de frames : 414
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/414.jpg
# Numero de frames : 415
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/415.jpg
# Numero de frames : 416
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/416.jpg
# Numero de frames : 417
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/417.jpg
# Numero de frames : 418
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/418.jpg
# Numero de frames : 419
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/419.jpg
# Numero de frames : 420
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/420.jpg
# Numero de frames : 421
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/421.jpg
# Numero de frames : 422
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/422.jpg
# Numero de frames : 423
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/423.jpg
# Numero de frames : 424
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/424.jpg
# Numero de frames : 425
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/425.jpg
# Numero de frames : 426
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/426.jpg
# Numero de frames : 427
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/427.jpg
# Numero de frames : 428
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/428.jpg
# Numero de frames : 429
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/429.jpg
# Numero de frames : 430
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/430.jpg
# Numero de frames : 431
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/431.jpg
# Numero de frames : 432
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/432.jpg
# Numero de frames : 433
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/433.jpg
# Numero de frames : 434
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/434.jpg
# Numero de frames : 435
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/435.jpg
# Numero de frames : 436
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/436.jpg
# Numero de frames : 437
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/437.jpg
# Numero de frames : 438
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/438.jpg
# Numero de frames : 439
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/439.jpg
# Numero de frames : 440
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/440.jpg
# Numero de frames : 441
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/441.jpg
# Numero de frames : 442
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/442.jpg
# Numero de frames : 443
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/443.jpg
# Numero de frames : 444
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/444.jpg
# Numero de frames : 445
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/445.jpg
# Numero de frames : 446
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/446.jpg
# Numero de frames : 447
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/447.jpg
# Numero de frames : 448
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/448.jpg
# Numero de frames : 449
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/449.jpg
# Numero de frames : 450
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/450.jpg
# Numero de frames : 451
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/451.jpg
# Numero de frames : 452
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/452.jpg
# Numero de frames : 453
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/453.jpg
# Numero de frames : 454
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/454.jpg
# Numero de frames : 455
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/455.jpg
# Numero de frames : 456
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/456.jpg
# Numero de frames : 457
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/457.jpg
# Numero de frames : 458
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/458.jpg
# Numero de frames : 459
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/459.jpg
# Numero de frames : 460
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/460.jpg
# Numero de frames : 461
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/461.jpg
# Numero de frames : 462
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/462.jpg
# Numero de frames : 463
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/463.jpg
# Numero de frames : 464
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/464.jpg
# Numero de frames : 465
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/465.jpg
# Numero de frames : 466
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/466.jpg
# Numero de frames : 467
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/467.jpg
# Numero de frames : 468
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/468.jpg
# Numero de frames : 469
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/469.jpg
# Numero de frames : 470
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/470.jpg
# Numero de frames : 471
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/471.jpg
# Numero de frames : 472
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/472.jpg
# Numero de frames : 473
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/473.jpg
# Numero de frames : 474
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/474.jpg
# Numero de frames : 475
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/475.jpg
# Numero de frames : 476
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/476.jpg
# Numero de frames : 477
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/477.jpg
# Numero de frames : 478
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/478.jpg
# Numero de frames : 479
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/479.jpg
# Numero de frames : 480
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/480.jpg
# Numero de frames : 481
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/481.jpg
# Numero de frames : 482
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/482.jpg
# Numero de frames : 483
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/483.jpg
# Numero de frames : 484
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/484.jpg
# Numero de frames : 485
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/485.jpg
# Numero de frames : 486
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/486.jpg
# Numero de frames : 487
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/487.jpg
# Numero de frames : 488
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/488.jpg
# Numero de frames : 489
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/489.jpg
# Numero de frames : 490
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/490.jpg
# Numero de frames : 491
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/491.jpg
# Numero de frames : 492
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/492.jpg
# Numero de frames : 493
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/493.jpg
# Numero de frames : 494
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/494.jpg
# Numero de frames : 495
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/495.jpg
# Numero de frames : 496
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/496.jpg
# Numero de frames : 497
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/497.jpg
# Numero de frames : 498
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/498.jpg
# Numero de frames : 499
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/499.jpg
# Numero de frames : 500
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/500.jpg
# Numero de frames : 501
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/501.jpg
# Numero de frames : 502
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/502.jpg
# Numero de frames : 503
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/503.jpg
# Numero de frames : 504
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/504.jpg
# Numero de frames : 505
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/505.jpg
# Numero de frames : 506
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/506.jpg
# Numero de frames : 507
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/507.jpg
# Numero de frames : 508
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/508.jpg
# Numero de frames : 509
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/509.jpg
# Numero de frames : 510
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/510.jpg
# Numero de frames : 511
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/511.jpg
# Numero de frames : 512
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/512.jpg
# Numero de frames : 513
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/513.jpg
# Numero de frames : 514
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/514.jpg
# Numero de frames : 515
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/515.jpg
# Numero de frames : 516
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/516.jpg
# Numero de frames : 517
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/517.jpg
# Numero de frames : 518
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/518.jpg
# Numero de frames : 519
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/519.jpg
# Numero de frames : 520
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/520.jpg
# Numero de frames : 521
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/521.jpg
# Numero de frames : 522
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/522.jpg
# Numero de frames : 523
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/523.jpg
# Numero de frames : 524
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/524.jpg
# Numero de frames : 525
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/525.jpg
# Numero de frames : 526
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/526.jpg
# Numero de frames : 527
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/527.jpg
# Numero de frames : 528
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/528.jpg
# Numero de frames : 529
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/529.jpg
# Numero de frames : 530
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/530.jpg
# Numero de frames : 531
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/531.jpg
# Numero de frames : 532
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/532.jpg
# Numero de frames : 533
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/533.jpg
# Numero de frames : 534
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/534.jpg
# Numero de frames : 535
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/535.jpg
# Numero de frames : 536
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/536.jpg
# Numero de frames : 537
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/537.jpg
# Numero de frames : 538
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/538.jpg
# Numero de frames : 539
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/539.jpg
# Numero de frames : 540
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/540.jpg
# Numero de frames : 541
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/541.jpg
# Numero de frames : 542
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/542.jpg
# Numero de frames : 543
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/543.jpg
# Numero de frames : 544
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/544.jpg
# Numero de frames : 545
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/545.jpg
# Numero de frames : 546
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/546.jpg
# Numero de frames : 547
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/547.jpg
# Numero de frames : 548
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/548.jpg
# Numero de frames : 549
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/549.jpg
# Numero de frames : 550
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/550.jpg
# Numero de frames : 551
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/551.jpg
# Numero de frames : 552
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/552.jpg
# Numero de frames : 553
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/553.jpg
# Numero de frames : 554
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/554.jpg
# Numero de frames : 555
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/555.jpg
# Numero de frames : 556
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/556.jpg
# Numero de frames : 557
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/557.jpg
# Numero de frames : 558
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/558.jpg
# Numero de frames : 559
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/559.jpg
# Numero de frames : 560
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/560.jpg
# Numero de frames : 561
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/561.jpg
# Numero de frames : 562
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/562.jpg
# Numero de frames : 563
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/563.jpg
# Numero de frames : 564
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/564.jpg
# Numero de frames : 565
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/565.jpg
# Numero de frames : 566
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/566.jpg
# Numero de frames : 567
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/567.jpg
# Numero de frames : 568
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/568.jpg
# Numero de frames : 569
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/569.jpg
# Numero de frames : 570
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/570.jpg
# Numero de frames : 571
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/571.jpg
# Numero de frames : 572
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/572.jpg
# Numero de frames : 573
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/573.jpg
# Numero de frames : 574
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/574.jpg
# Numero de frames : 575
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/575.jpg
# Numero de frames : 576
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/576.jpg
# Numero de frames : 577
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/577.jpg
# Numero de frames : 578
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/578.jpg
# Numero de frames : 579
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/579.jpg
# Numero de frames : 580
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/580.jpg
# Numero de frames : 581
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/581.jpg
# Numero de frames : 582
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/582.jpg
# Numero de frames : 583
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/583.jpg
# Numero de frames : 584
# El archivo fue escrito en :{0} /content/drive/MyDrive/FasterRCNN/video2/584.jpg
# Numero de frames : 585
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-16c72a9261b3> in <module>()
#      52           ROIs = ROIs_padded
#      53
# ---> 54       [P_cls, P_regr] = model_classifier_only.predict([F, ROIs])
#      55
#      56       # Calculate bboxes coordinates on resized image
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1976       callbacks.on_predict_begin()
#    1977       batch_outputs = None
# -> 1978       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1979         with data_handler.catch_stop_iteration():
#    1980           for step in data_handler.steps():
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1189     """Yields `(epoch, tf.data.Iterator)`."""
#    1190     with self._truncate_execution_to_epoch():
# -> 1191       data_iterator = iter(self._dataset)
#    1192       for epoch in range(self._initial_epoch, self._epochs):
#    1193         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     484     if context.executing_eagerly() or ops.inside_function():
#     485       with ops.colocate_with(self._variant_tensor):
# --> 486         return iterator_ops.OwnedIterator(self)
#     487     else:
#     488       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     753             "When `dataset` is provided, `element_spec` and `components` must "
#     754             "not be specified.")
# --> 755       self._create_iterator(dataset)
#     756
#     757     self._get_next_call_count = 0
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     785                 output_types=self._flat_output_types,
#     786                 output_shapes=self._flat_output_shapes))
# --> 787         gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     788         # Delete the resource when this object is deleted
#     789         self._resource_deleter = IteratorResourceDeleter(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3314     try:
#    3315       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 3316         _ctx, "MakeIterator", name, dataset, iterator)
#    3317       return _result
#    3318     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
#CREACION DEL VIDEO:
from cv2 import VideoWriter, VideoWriter_fourcc, imread,resize
import glob
images = list(glob.iglob(os.path.join('/content/drive/MyDrive/FasterRCNN/video2','*.jpg')))
images = sorted(images,key=lambda x:float(os.path.split(x)[1][:-3]))
video_output = os.path.join('/content/drive/MyDrive/FasterRCNN','acuario_proce.mp4')
fourcc =VideoWriter_fourcc(*'FMP4')
vid =None
size= None
is_color = True
for image in images:
  img = imread(image)
  if vid is None:
    if size is None:
      size = img.shape[1], img.shape[0]
    vid = VideoWriter(video_output, fourcc, float(30), size, is_color)
  if size[0] != img.shape[1] and size[1] != img.shape[0]:
    img = resize(img,size)
  vid.write(img)
vid.release()
